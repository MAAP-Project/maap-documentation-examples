# %%
import copy
import hashlib
import json
import requests
import time
import matplotlib.pyplot as plt
import os
from pprint import pprint
import shutil
from pathlib import Path
import random
import re
from maap.maap import MAAP
# invoke the MAAP constructor using the maap_host argument
maap = MAAP(maap_host='api.ops.maap-project.org')

# %% [markdown]
# # MAAP Data Store Performance Comparison with NASA Operational Data Store
#
# In this notebook we compare the performance of downloading data from NASA's operational CMR vs the cost to access and store data in MAAP's S3 data store

# %% [markdown]
# ## Step 1: Define some collections to test
#
# The collections below are cataloged in both MAAP's CMR and NASA's Operational CMR. The MAAP versions exist in an S3 data store in us-west-2 (s3://nasa-maap-data-store). The NASA versions exist in on-prem data stores at various DAACs and are accessible over HTTPS.

# %%
POLARIMETRIC = {
    'short_name': 'Polarimetric_CT_1601',
    'version': '1',
    'concept_id': 'C1538765745-ORNL_DAAC',
    'provider': 'ORNL_DAAC',
    'granules': []
}
AfriSAR_AGB_Maps_1681 = {
    'short_name': 'AfriSAR_AGB_Maps_1681',
    'version': '1',
    'concept_id': 'C1612508242-ORNL_DAAC',
    'provider': 'ORNL_DAAC',
    'granules': []    
}
ABLVIS2 = {
    'short_name': 'ABLVIS2',
    'version': '1',
    'concept_id': 'C1513105984-NSIDC_ECS',
    'provider': 'NSIDC_ECS',
    'granules': []    
}
ALOS_PSR_RTC_HIGH = {
    'short_name': 'ALOS_PSR_RTC_HIGH',
    'version': '1',
    'concept_id': 'C1206487504-ASF',
    'provider': 'ASF',
    'granules': []    
}
ALOS_PSR_L15 = {
    'short_name': 'ALOS_PSR_L1.5',
    'version': '1',
    'concept_id': 'C1206485940-ASF',
    'provider': 'ASF',
    'granules': []
}
LVISF1B = {
    'short_name': 'LVISF1B',
    'version': '1',
    'concept_id': 'C1723866745-NSIDC_ECS',
    'provider': 'NSIDC_ECS',
    'granules': []
}
GEDIL2A = {
    'short_name': 'GEDI02_A',
    'version': '002',
    'concept_id': 'C1908348134-LPDAAC_ECS',
    'provider': 'LPDAAC_ECS',
    'granules': []
}
ATL08 = {
    'short_name': 'ATL08',
    'version': '005',
    'concept_id': 'C2144424132-NSIDC_ECS',
    'provider': 'NSIDC_ECS',
    'granules': []
}

collections = {
    collection['short_name']: collection for collection in
    [ POLARIMETRIC, AfriSAR_AGB_Maps_1681, ABLVIS2, ALOS_PSR_RTC_HIGH, ALOS_PSR_L15, LVISF1B, GEDIL2A, ATL08 ]
}
collection_results = copy.deepcopy(collections)

# %%
# Define some directories to store the data in temporarily.
nasa_operational_dir = 'test_files/nasa_operational'
maap_dir = 'test_files/maap'
Path(nasa_operational_dir).mkdir(parents=True, exist_ok=True)
Path(maap_dir).mkdir(parents=True, exist_ok=True)

# %%
# Function to capture time to download.
def time_download(granule, directory):
    download_start_time = time.time()
    nasa_file = granule.getData(directory)
    download_end_time = time.time()
    download_end_time - download_start_time 
    return [nasa_file, download_end_time - download_start_time ]

# %% [markdown]
# ## Step 2: Test download
#
# For each collection, download the granule from NASA's Operational Data Store and from MAAP's S3 data store. Also get the file size and make sure the checksums match.

# %%
limit = 100
times_per_collection = 5

for collection in collections.values():
    print(collection)
    maap_collection = {
        'short_name': collection['short_name'],
        'version': collection['version']
    }
    maap_search_results = maap.searchGranule(
        cmr_host='cmr.maap-project.org',
        limit=limit,
        **maap_collection
    )
    # Test a few random granules in this collection
    for idx in range(times_per_collection):
        granule = maap_search_results[random.randint(0, len(maap_search_results) - 1)]
        granule_ur = granule['Granule']['GranuleUR']
        print(f"Downloading {granule_ur} from MAAP")
        maap_file, maap_time = time_download(granule, maap_dir)
        print(f"Time to download from MAAP data store {maap_time}")
        maap_hexdigest = hashlib.md5(open(maap_file,'rb').read()).hexdigest()

        # NASA's operational CMR
        nasa_search_results = maap.searchGranule(
            cmr_host='cmr.earthdata.nasa.gov',
            limit=limit,
            granule_ur=granule_ur,
            **collection,
        )
        granule = nasa_search_results[0]  
        print(f"Downloading {granule['Granule']['GranuleUR']} from NASA")        
        nasa_file, nasa_time = time_download(granule, nasa_operational_dir)
        print(f"Time to download from nasa operational data store {nasa_time}")
        nasa_hexdigest = hashlib.md5(open(nasa_file,'rb').read()).hexdigest()
        # Make sure the files match
        print(nasa_hexdigest)
        print(maap_hexdigest)         
        assert(nasa_hexdigest == maap_hexdigest)       

        file_size = os.path.getsize(maap_file)        
        granule_results = {
            'granule_ur': granule_ur,
            'nasa_time': nasa_time,
            'maap_time': maap_time,
            'file_size': file_size,
            'time_ratio': nasa_time/maap_time
        }
        collection_results[collection['short_name']]['granules'].append(granule_results)
# Out:
# {'short_name': 'Polarimetric_CT_1601', 'version': '1', 'concept_id': 'C1538765745-ORNL_DAAC', 'provider': 'ORNL_DAAC', 'granules': []}
# Downloading Polarimetric_CT.mondah_pct_legendre_function_f0.tif from MAAP
# Time to download from MAAP data store 0.43908047676086426
# Downloading Polarimetric_CT.mondah_pct_legendre_function_f0.tif from NASA
# Time to download from nasa operational data store 4.086672067642212
# 2481dca1d1267282511b986917ee77c4
# 2481dca1d1267282511b986917ee77c4
# Downloading Polarimetric_CT.lope_local_incidence_angle.tif from MAAP
# Time to download from MAAP data store 0.407010555267334
# Downloading Polarimetric_CT.lope_local_incidence_angle.tif from NASA
# Time to download from nasa operational data store 3.3410191535949707
# a331f16095cfaff560a9bf609893d598
# a331f16095cfaff560a9bf609893d598
# Downloading Polarimetric_CT.mondah_polinsar_vertical_wavenumber.tif from MAAP
# Time to download from MAAP data store 0.5069441795349121
# Downloading Polarimetric_CT.mondah_polinsar_vertical_wavenumber.tif from NASA
# Time to download from nasa operational data store 3.5780603885650635
# 3a96287fa538993409973c158acf8b42
# 3a96287fa538993409973c158acf8b42
# Downloading Polarimetric_CT.lope_pct_coefficient_a20.tif from MAAP
# Time to download from MAAP data store 0.3696436882019043
# Downloading Polarimetric_CT.lope_pct_coefficient_a20.tif from NASA
# Time to download from nasa operational data store 3.2396702766418457
# 0838a83fc1ffcd445d0370c23715b2d4
# 0838a83fc1ffcd445d0370c23715b2d4
# Downloading Polarimetric_CT.rabi_pct_legendre_function_f1.tif from MAAP
# Time to download from MAAP data store 0.0021543502807617188
# Downloading Polarimetric_CT.rabi_pct_legendre_function_f1.tif from NASA
# Time to download from nasa operational data store 0.00197601318359375
# e0267355bf5bc8839502095c354ace58
# e0267355bf5bc8839502095c354ace58
# {'short_name': 'AfriSAR_AGB_Maps_1681', 'version': '1', 'concept_id': 'C1612508242-ORNL_DAAC', 'provider': 'ORNL_DAAC', 'granules': []}
# Downloading AfriSAR_AGB_Maps.Mondah_AGB_50m.tif from MAAP
# Time to download from MAAP data store 0.0021283626556396484
# Downloading AfriSAR_AGB_Maps.Mondah_AGB_50m.tif from NASA
# Time to download from nasa operational data store 0.002148151397705078
# 4b778ddbea9e1bd49f3678e78c74436b
# 4b778ddbea9e1bd49f3678e78c74436b
# Downloading AfriSAR_AGB_Maps.Mondah_AGB_50m.tif from MAAP
# Time to download from MAAP data store 0.0001266002655029297
# Downloading AfriSAR_AGB_Maps.Mondah_AGB_50m.tif from NASA
# Time to download from nasa operational data store 0.0005352497100830078
# 4b778ddbea9e1bd49f3678e78c74436b
# 4b778ddbea9e1bd49f3678e78c74436b
# Downloading AfriSAR_AGB_Maps.Lope_AGB_50m.tif from MAAP
# Time to download from MAAP data store 0.0021390914916992188
# Downloading AfriSAR_AGB_Maps.Lope_AGB_50m.tif from NASA
# Time to download from nasa operational data store 0.0021276473999023438
# 0e0df791191e129355912ae06a948f55
# 0e0df791191e129355912ae06a948f55
# Downloading AfriSAR_AGB_Maps.Mabounie_AGB_50m.tif from MAAP
# Time to download from MAAP data store 0.21534085273742676
# Downloading AfriSAR_AGB_Maps.Mabounie_AGB_50m.tif from NASA
# Time to download from nasa operational data store 2.6952385902404785
# 346716ac16211e54eb6b82c17189e7ca
# 346716ac16211e54eb6b82c17189e7ca
# Downloading AfriSAR_AGB_Maps.Lope_AGB_50m.tif from MAAP
# Time to download from MAAP data store 0.0003991127014160156
# Downloading AfriSAR_AGB_Maps.Lope_AGB_50m.tif from NASA
# Time to download from nasa operational data store 0.0005395412445068359
# 0e0df791191e129355912ae06a948f55
# 0e0df791191e129355912ae06a948f55
# {'short_name': 'ABLVIS2', 'version': '1', 'concept_id': 'C1513105984-NSIDC_ECS', 'provider': 'NSIDC_ECS', 'granules': []}
# Downloading SC:ABLVIS2.001:129489157 from MAAP
# Time to download from MAAP data store 1.9958808422088623
# Downloading SC:ABLVIS2.001:129489157 from NASA
# Time to download from nasa operational data store 6.7455666065216064
# 8e79b878f974fce78e5685042cce9e23
# 8e79b878f974fce78e5685042cce9e23
# Downloading SC:ABLVIS2.001:129489357 from MAAP
# Time to download from MAAP data store 2.043862819671631
# Downloading SC:ABLVIS2.001:129489357 from NASA
# Time to download from nasa operational data store 7.915405750274658
# 760163e11b608ecc139b976aa77d5546
# 760163e11b608ecc139b976aa77d5546
# Downloading SC:ABLVIS2.001:129490070 from MAAP
# Time to download from MAAP data store 2.013643503189087
# Downloading SC:ABLVIS2.001:129490070 from NASA
# Time to download from nasa operational data store 7.408010005950928
# 02043e8d635abc4e25b0b5da1647dc18
# 02043e8d635abc4e25b0b5da1647dc18
# Downloading SC:ABLVIS2.001:129489400 from MAAP
# Time to download from MAAP data store 2.011291265487671
# Downloading SC:ABLVIS2.001:129489400 from NASA
# Time to download from nasa operational data store 6.909359693527222
# 62a4ba2af9ba1def920f1057dd6c3e8b
# 62a4ba2af9ba1def920f1057dd6c3e8b
# Downloading SC:ABLVIS2.001:129489362 from MAAP
# Time to download from MAAP data store 1.9825031757354736
# Downloading SC:ABLVIS2.001:129489362 from NASA
# Time to download from nasa operational data store 7.748239278793335
# b633f2bd566cbf52cdb60e973c189917
# b633f2bd566cbf52cdb60e973c189917
# {'short_name': 'ALOS_PSR_RTC_HIGH', 'version': '1', 'concept_id': 'C1206487504-ASF', 'provider': 'ASF', 'granules': []}
# Downloading ALPSRP016457020-RTC_HI_RES from MAAP
# Time to download from MAAP data store 3.4550957679748535
# Downloading ALPSRP016457020-RTC_HI_RES from NASA
# Time to download from nasa operational data store 13.809831142425537
# 45637a49f9948c35004c8e83948bc566
# 45637a49f9948c35004c8e83948bc566
# Downloading ALPSRP024917190-RTC_HI_RES from MAAP
# Time to download from MAAP data store 0.0021910667419433594
# Downloading ALPSRP024917190-RTC_HI_RES from NASA
# Time to download from nasa operational data store 0.002303600311279297
# fd670d787258269bfb48e67616802056
# fd670d787258269bfb48e67616802056
# Downloading ALPSRP018207100-RTC_HI_RES from MAAP
# Time to download from MAAP data store 3.6011903285980225
# Downloading ALPSRP018207100-RTC_HI_RES from NASA
# Time to download from nasa operational data store 14.036657333374023
# 26bb5632c428d33dfa38f32a60232f21
# 26bb5632c428d33dfa38f32a60232f21
# Downloading ALPSRP020687060-RTC_HI_RES from MAAP
# Time to download from MAAP data store 3.503342628479004
# Downloading ALPSRP020687060-RTC_HI_RES from NASA
# Time to download from nasa operational data store 14.074237823486328
# a00f8878508947e92896d1949952867c
# a00f8878508947e92896d1949952867c
# Downloading ALPSRP018210080-RTC_HI_RES from MAAP
# Time to download from MAAP data store 3.7102103233337402
# Downloading ALPSRP018210080-RTC_HI_RES from NASA
# Time to download from nasa operational data store 13.414156436920166
# 2d15f2d9e0e67e34706501c20e1c04ab
# 2d15f2d9e0e67e34706501c20e1c04ab
# {'short_name': 'ALOS_PSR_L1.5', 'version': '1', 'concept_id': 'C1206485940-ASF', 'provider': 'ASF', 'granules': []}
# Downloading ALPSRP020840020-L1.5 from MAAP
# Time to download from MAAP data store 2.741194009780884
# Downloading ALPSRP020840020-L1.5 from NASA
# Time to download from nasa operational data store 10.533200740814209
# 8929945c86f2b2ae889406994942bb20
# 8929945c86f2b2ae889406994942bb20
# Downloading ALPSRP022590050-L1.5 from MAAP
# Time to download from MAAP data store 3.0073697566986084
# Downloading ALPSRP022590050-L1.5 from NASA
# Time to download from nasa operational data store 11.371469974517822
# b22124778ec559740c0231af3b6be262
# b22124778ec559740c0231af3b6be262
# Downloading ALPSRP020840060-L1.5 from MAAP
# Time to download from MAAP data store 2.680171251296997
# Downloading ALPSRP020840060-L1.5 from NASA
# Time to download from nasa operational data store 10.824681997299194
# 0a8f57d373030e070313f8e7e9942461
# 0a8f57d373030e070313f8e7e9942461
# Downloading ALPSRP021860040-L1.5 from MAAP
# Time to download from MAAP data store 3.0922539234161377
# Downloading ALPSRP021860040-L1.5 from NASA
# Time to download from nasa operational data store 12.395812034606934
# bd164ac31903636149e5aa1393a39f21
# bd164ac31903636149e5aa1393a39f21
# Downloading ALPSRP022590030-L1.5 from MAAP
# Time to download from MAAP data store 2.6280550956726074
# Downloading ALPSRP022590030-L1.5 from NASA
# Time to download from nasa operational data store 10.468804359436035
# 3e0903e1d9a092c3a7fb3981e383f29a
# 3e0903e1d9a092c3a7fb3981e383f29a
# {'short_name': 'LVISF1B', 'version': '1', 'concept_id': 'C1723866745-NSIDC_ECS', 'provider': 'NSIDC_ECS', 'granules': []}
# Downloading SC:LVISF1B.001:177728385 from MAAP
# Time to download from MAAP data store 12.752955675125122
# Downloading SC:LVISF1B.001:177728385 from NASA
# Time to download from nasa operational data store 109.95403385162354
# 84c0aefb709fb1b12e535cce128b5d70
# 84c0aefb709fb1b12e535cce128b5d70
# Downloading SC:LVISF1B.001:177728684 from MAAP
# Time to download from MAAP data store 13.029934644699097
# Downloading SC:LVISF1B.001:177728684 from NASA
# Time to download from nasa operational data store 109.8102159500122
# 7e8a4da09018d49955eeaab4e71e46b3
# 7e8a4da09018d49955eeaab4e71e46b3
# Downloading SC:LVISF1B.001:177728745 from MAAP
# Time to download from MAAP data store 12.872120141983032
# Downloading SC:LVISF1B.001:177728745 from NASA
# Time to download from nasa operational data store 108.63189339637756
# e393027133666084a8b84f33b51b136e
# e393027133666084a8b84f33b51b136e
# Downloading SC:LVISF1B.001:177727416 from MAAP
# Time to download from MAAP data store 12.768803119659424
# Downloading SC:LVISF1B.001:177727416 from NASA
# Time to download from nasa operational data store 109.99079465866089
# 3a377053d75afe0f66b88fb8f94b5526
# 3a377053d75afe0f66b88fb8f94b5526
# Downloading SC:LVISF1B.001:177728760 from MAAP
# Time to download from MAAP data store 12.790665864944458
# Downloading SC:LVISF1B.001:177728760 from NASA
# Time to download from nasa operational data store 109.77734446525574
# e145cc9b2106c961f4f0c6111b71076d
# e145cc9b2106c961f4f0c6111b71076d
# {'short_name': 'GEDI02_A', 'version': '002', 'concept_id': 'C1908348134-LPDAAC_ECS', 'provider': 'LPDAAC_ECS', 'granules': []}
# Downloading SC:GEDI02_A.002:2432350834 from MAAP
# Time to download from MAAP data store 36.864935874938965
# Downloading SC:GEDI02_A.002:2432350834 from NASA
# Time to download from nasa operational data store 166.8232283592224
# bd8593edf602f0fa9147d288fc53d9a7
# bd8593edf602f0fa9147d288fc53d9a7
# Downloading SC:GEDI02_A.002:2432371476 from MAAP
# Time to download from MAAP data store 30.136855363845825
# Downloading SC:GEDI02_A.002:2432371476 from NASA
# Time to download from nasa operational data store 138.4912166595459
# fce576b2dda98f7a434f61731abf1acb
# fce576b2dda98f7a434f61731abf1acb
# Downloading SC:GEDI02_A.002:2432356971 from MAAP
# Time to download from MAAP data store 28.78805136680603
# Downloading SC:GEDI02_A.002:2432356971 from NASA
# Time to download from nasa operational data store 121.44011235237122
# c5edd569aad0588b1e4d7f8a90ca9a62
# c5edd569aad0588b1e4d7f8a90ca9a62
# Downloading SC:GEDI02_A.002:2432359402 from MAAP
# Time to download from MAAP data store 6.824148893356323
# Downloading SC:GEDI02_A.002:2432359402 from NASA
# Time to download from nasa operational data store 39.23574352264404
# 4023322c3bbd4e45b3a4ddac920c9602
# 4023322c3bbd4e45b3a4ddac920c9602
# Downloading SC:GEDI02_A.002:2432354237 from MAAP
# Time to download from MAAP data store 0.0021636486053466797
# Downloading SC:GEDI02_A.002:2432354237 from NASA
# Time to download from nasa operational data store 0.0021953582763671875
# 4933bf4cb0112e53fac06701c0b34cf9
# 4933bf4cb0112e53fac06701c0b34cf9
# {'short_name': 'ATL08', 'version': '005', 'concept_id': 'C2144424132-NSIDC_ECS', 'provider': 'NSIDC_ECS', 'granules': []}
# Downloading SC:ATL08.005:228968235 from MAAP
# Time to download from MAAP data store 0.002353668212890625
# Downloading SC:ATL08.005:228968235 from NASA
# Time to download from nasa operational data store 0.0022056102752685547
# 2e4923b79c15a916bf536b32589a03ee
# 2e4923b79c15a916bf536b32589a03ee
# Downloading SC:ATL08.005:228994868 from MAAP
# Time to download from MAAP data store 0.4539620876312256
# Downloading SC:ATL08.005:228994868 from NASA
# Time to download from nasa operational data store 3.097473621368408
# 0e51fd20f947a5c3e298267717588e08
# 0e51fd20f947a5c3e298267717588e08
# Downloading SC:ATL08.005:228968212 from MAAP
# Time to download from MAAP data store 0.8059375286102295
# Downloading SC:ATL08.005:228968212 from NASA
# Time to download from nasa operational data store 4.512359619140625
# 70ed9ce5314730cdecb7b24b17f7f70b
# 70ed9ce5314730cdecb7b24b17f7f70b
# Downloading SC:ATL08.005:229004918 from MAAP
# Time to download from MAAP data store 0.37488484382629395
# Downloading SC:ATL08.005:229004918 from NASA
# Time to download from nasa operational data store 2.8398079872131348
# 38ca9b174946eef75a8a4de3019bf36f
# 38ca9b174946eef75a8a4de3019bf36f
# Downloading SC:ATL08.005:228988739 from MAAP
# Time to download from MAAP data store 2.4704854488372803
# Downloading SC:ATL08.005:228988739 from NASA
# Time to download from nasa operational data store 9.89757752418518
# 281b59941a7da470e79001b3de7a48b5
# 281b59941a7da470e79001b3de7a48b5

# %% [markdown]
# ## Step 3: Plot the data
#
# As expected, we see that downloading the data from MAAP's S3 is faster. It takes anywhere from twice to 15 times as long to download data.

# %%
all_granules = []
[all_granules.extend(collection['granules']) for collection in collection_results.values()]
nasa_times = [granule['nasa_time'] for granule in all_granules]
maap_times = [granule['maap_time'] for granule in all_granules]
file_sizes = [granule['file_size']/1e9 for granule in all_granules]
ratios = [granule['time_ratio'] for granule in all_granules]

plt.scatter(file_sizes, nasa_times, label='NASA Operational')
plt.scatter(file_sizes, maap_times, label='MAAP Data Store')
plt.legend()
plt.xlabel('File size in GB')
plt.ylabel('Download time in seconds')
plt.show()

# %%
plt.scatter(file_sizes, ratios, label='Ratio NASA/MAAP download time')
plt.legend()
plt.xlabel('File size in GB')
plt.ylabel('Relative download time NASA vs MAAP')
plt.show()

# %%
import os

collection_directories = [f"{collection['short_name']}___{collection['version']}" for collection in collection_results.values()]
sizes = dict()

for dir in collection_directories:
    location = f"nasa-maap-data-store/file-staging/nasa-map/{dir}"
    print(f"s3://{location}/")
    cmd = f"aws s3 ls --summarize --human-readable --recursive s3://{location}/ | grep 'Total'"
    sizes[dir] = os.popen(cmd).read()
    print(sizes)
# Out:
# s3://nasa-maap-data-store/file-staging/nasa-map/Polarimetric_CT_1601___1/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n'}
# s3://nasa-maap-data-store/file-staging/nasa-map/AfriSAR_AGB_Maps_1681___1/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n', 'AfriSAR_AGB_Maps_1681___1': 'Total Objects: 8\n   Total Size: 576.3 KiB\n'}
# s3://nasa-maap-data-store/file-staging/nasa-map/ABLVIS2___1/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n', 'AfriSAR_AGB_Maps_1681___1': 'Total Objects: 8\n   Total Size: 576.3 KiB\n', 'ABLVIS2___1': 'Total Objects: 1051\n   Total Size: 103.9 GiB\n'}
# s3://nasa-maap-data-store/file-staging/nasa-map/ALOS_PSR_RTC_HIGH___1/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n', 'AfriSAR_AGB_Maps_1681___1': 'Total Objects: 8\n   Total Size: 576.3 KiB\n', 'ABLVIS2___1': 'Total Objects: 1051\n   Total Size: 103.9 GiB\n', 'ALOS_PSR_RTC_HIGH___1': 'Total Objects: 4021\n   Total Size: 532.5 GiB\n'}
# s3://nasa-maap-data-store/file-staging/nasa-map/ALOS_PSR_L1.5___1/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n', 'AfriSAR_AGB_Maps_1681___1': 'Total Objects: 8\n   Total Size: 576.3 KiB\n', 'ABLVIS2___1': 'Total Objects: 1051\n   Total Size: 103.9 GiB\n', 'ALOS_PSR_RTC_HIGH___1': 'Total Objects: 4021\n   Total Size: 532.5 GiB\n', 'ALOS_PSR_L1.5___1': 'Total Objects: 5356\n   Total Size: 356.3 GiB\n'}
# s3://nasa-maap-data-store/file-staging/nasa-map/LVISF1B___1/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n', 'AfriSAR_AGB_Maps_1681___1': 'Total Objects: 8\n   Total Size: 576.3 KiB\n', 'ABLVIS2___1': 'Total Objects: 1051\n   Total Size: 103.9 GiB\n', 'ALOS_PSR_RTC_HIGH___1': 'Total Objects: 4021\n   Total Size: 532.5 GiB\n', 'ALOS_PSR_L1.5___1': 'Total Objects: 5356\n   Total Size: 356.3 GiB\n', 'LVISF1B___1': 'Total Objects: 2528\n   Total Size: 2.2 TiB\n'}
# s3://nasa-maap-data-store/file-staging/nasa-map/GEDI02_A___002/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n', 'AfriSAR_AGB_Maps_1681___1': 'Total Objects: 8\n   Total Size: 576.3 KiB\n', 'ABLVIS2___1': 'Total Objects: 1051\n   Total Size: 103.9 GiB\n', 'ALOS_PSR_RTC_HIGH___1': 'Total Objects: 4021\n   Total Size: 532.5 GiB\n', 'ALOS_PSR_L1.5___1': 'Total Objects: 5356\n   Total Size: 356.3 GiB\n', 'LVISF1B___1': 'Total Objects: 2528\n   Total Size: 2.2 TiB\n', 'GEDI02_A___002': 'Total Objects: 47187\n   Total Size: 65.5 TiB\n'}
# s3://nasa-maap-data-store/file-staging/nasa-map/ATL08___005/
# {'Polarimetric_CT_1601___1': 'Total Objects: 104\n   Total Size: 448.5 MiB\n', 'AfriSAR_AGB_Maps_1681___1': 'Total Objects: 8\n   Total Size: 576.3 KiB\n', 'ABLVIS2___1': 'Total Objects: 1051\n   Total Size: 103.9 GiB\n', 'ALOS_PSR_RTC_HIGH___1': 'Total Objects: 4021\n   Total Size: 532.5 GiB\n', 'ALOS_PSR_L1.5___1': 'Total Objects: 5356\n   Total Size: 356.3 GiB\n', 'LVISF1B___1': 'Total Objects: 2528\n   Total Size: 2.2 TiB\n', 'GEDI02_A___002': 'Total Objects: 47187\n   Total Size: 65.5 TiB\n', 'ATL08___005': 'Total Objects: 172869\n   Total Size: 14.9 TiB\n'}

# %%
total_size = 0

for sizes_str in sizes.values():
    volume_str_match = re.match('.+Total Size: (\d+.\d+) (\w)iB', sizes_str, flags=re.DOTALL)
    if volume_str_match:
        volume = volume_str_match[1]
        unit = volume_str_match[2]
        if unit == 'K':
            total_size += float(volume)*1024
        elif unit == 'M':
            total_size += float(volume)*1024*1024        
        elif unit == 'G':
            total_size += float(volume)*1024*1024*1024
        elif unit == 'T':
            total_size += float(volume)*1024*1024*1024*1024
    
total_size_in_gb = total_size/(1024*1024*1024)
total_size_in_gb
# Out:
# 85575.53853788377

# %%
# average time to download data from NASA
` = (sum(nasa_times)/len(nasa_times))/sum(file_sizes)
average_time_per_gb

# total size of these collections
total_size_of_collections = total_size_in_gb # GB

# multiple average_time_per_gb times the total size of these 5 collections
total_time = average_time_per_gb * total_size_of_collections
total_time_in_hours = total_time / 60

# calculate the cost of compute for m5.large
total_cost_to_download_all = 0.096 * total_time_in_hours
f"total cost to download all: ${round(total_cost_to_download_all, 2)}"
# Out:
# 'total cost to download all: $266.43'

# %%
# cost to archive + store all
cost_for_maap_data_store = total_size_of_collections * 0.0230000000
cost_for_maap_data_store

# cost to ingest + publish all
# Below we estimate the cost to run veda-data-pipeline lambdas for 1.2GB of data, which is from ICESat-2 Boreal publication Feb 21, 2023.
lambda_time_per_gb = 745604 / 1000 / 1.2
# cost for lambda execution time
lambda_time_for_for_all = lambda_time_per_gb * total_size_of_collections # for every GB-second
total_processing_cost = lambda_time_for_for_all * 0.0000166667 * 0.5 
print(f"Cost to catalog the data ${round(total_processing_cost, 2)} (incurred only once).")
print(f"Monthly cost to store the data ${round(cost_for_maap_data_store, 2)}")
print(f"Cost to catalog and store data for these collections is estimated at ${round(cost_for_maap_data_store + total_processing_cost, 2)}")
# Out:
# Cost to catalog the data $443.09 (incurred only once).
# Monthly cost to store the data $1968.24
# Cost to catalog and store data for these collections is estimated at $2411.33

# %% [markdown]
# ## In conclusion
#
# ### The estimated cost to catalog and store data is comparable to downloading the same data from NASA's operational data store at least 5 times every month.
#
# In the most recent test, the relative cost was actually 10 times - in other words the same data must be downloaded 10 times in order to cover the cost of storing the same data in S3.
#
# Additional considerations:
# * The estimated cost to transfer data in from NASA Operational Data Stores is only for EC2 compute time, the cost to transfer data into EC2 is $0, see https://aws.amazon.com/ec2/pricing/on-demand/#Data_Transfer.
# * the DPS caches files, so downloading more than once may not be necessary.
# * The estimate to create copies of data does not include development hours to maintain up to date archives. We estimate at least 1 FTE to maintain up to date copies of NASA data.
# * In previous metrics, we found that only about 1% of the data is being accessed. See [NASA MAAP Data System Update: October 2022](https://docs.google.com/presentation/d/1mhlF-sVIBZXOyq_o0W6DiRgYp3y9fa_WfCFkZywYRlQ/edit#slide=id.g16ca19faf11_0_5)

# %% [markdown]
# <img src="aws_data_transfer_in_costs.png"  width="700" style="border: 1px solid #555;">

# %% [markdown]
# ## Clean up

# %%
shutil.rmtree('test_files')
