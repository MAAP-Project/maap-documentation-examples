# %%
from maap.maap import MAAP
# import printing package to help display outputs
from pprint import pprint
import os
import requests
import shutil

# %%
# this code is used to determine which datasets in MAAP CMR we should propose to offer in STAC because they are not discoverable and accessible in NASA's operational CMR.
URL = 'https://cmr.maap-project.org/search/collections.json?page_size=100'

# invoke the MAAP search client
maap = MAAP(maap_host='api.ops.maap-project.org')
# os.mkdir('tmp')

response = requests.get(URL)
not_in_cmr = []
in_cmr_can_access = []
in_cmr_cannot_access = [] 
for collection in response.json()['feed']['entry']:
    short_name, version, title = collection['short_name'], collection['version_id'], collection['title']
        
    # search NASA's CMR for the collection
    # 'AfriSAR_AGB_Maps_1681'
    results = maap.searchGranule(
        cmr_host='cmr.earthdata.nasa.gov',
        short_name=short_name,
        version=version,
    )
    if len(results) == 0:
        if version.startswith("00"):
            version = version.replace("00", "")
        results = maap.searchGranule(
            cmr_host='cmr.earthdata.nasa.gov',
            short_name=short_name,
            version=version,
        )        
    if len(results) > 0:
        # the collection IS in NASA's CMR and we can access it via maap-py, we don't need to catalog it in STAC
        print(f"Found granules for {short_name}, version {version}. Testing download...")
        print(f"Collection title is {title}")
        try:
            downloadedFile = results[0].getData('tmp')
            print(f"Downloaded file {downloadedFile}")
            file_size = os.path.getsize(downloadedFile)
            print("File Size is :", file_size, "bytes")
            if file_size < 1000:
                print(downloadedFile.read())
                print(f"Pretty sure {downloadedFile} is NOT a valid file and we should propose to catalog {short_name}, version {version}")
            else:
                in_cmr_can_access.append([title, short_name, version])
                print(f"Pretty sure {downloadedFile} is a valid file.")
        except Exception as e:
            in_cmr_cannot_access.append([title, short_name, version])
            print(f"Cannot access {results[0]._location} from {short_name}, version {version}")
            print(e)

    # if the collection isn't in NASA's CMR, we will propose to keep it
    else:   
        not_in_cmr.append([title, short_name, version])
        print(f"{short_name}, version {version} not in NASA's operational CMR.")
        
        
print("Not in CMR:")
print(*not_in_cmr, sep='\n')

print("Can access:")
print(*in_cmr_can_access, sep='\n')

print("Cannot access:")
print(*in_cmr_cannot_access, sep='\n')

shutil.rmtree('tmp')
# Out:
# Found granules for ABLVIS1B, version 1. Testing download...
# Collection title is ABoVE LVIS L1B Geolocated Return Energy Waveforms V001
# Downloaded file tmp/LVIS1B_ABoVE2017_0629_R1803_056233.h5
# File Size is : 995295392 bytes
# Pretty sure tmp/LVIS1B_ABoVE2017_0629_R1803_056233.h5 is a valid file.
# Found granules for ABLVIS2, version 1. Testing download...
# Collection title is ABoVE LVIS L2 Geolocated Surface Elevation Product V001
# Downloaded file tmp/LVIS2_ABoVE2017_0629_R1803_056233.TXT
# File Size is : 106921165 bytes
# Pretty sure tmp/LVIS2_ABoVE2017_0629_R1803_056233.TXT is a valid file.
# Found granules for ALOS_PSR_RTC_HIGH, version 1. Testing download...
# Collection title is Advance Land Observing Satellite Phased Array type L-band Synthetic Aperture Radar Radiometric Terrain-Corrected High Resolution products, Equatorial Western Africa, May 2006-March 2011
# Downloaded file tmp/AP_01635_FBS_F0340_RT1.zip
# File Size is : 151904490 bytes
# Pretty sure tmp/AP_01635_FBS_F0340_RT1.zip is a valid file.
# Found granules for ALOS_PSR_L1.5, version 1. Testing download...
# Collection title is Advanced Land Observation Satellite (ALOS) Phased Array L-band Synthetic Aperture Radar, Equatorial Western Africa, May 2006-March 2011
# Downloaded file tmp/ALPSRP016350310-L1.5.zip
# File Size is : 187166492 bytes
# Pretty sure tmp/ALPSRP016350310-L1.5.zip is a valid file.
# Found granules for AFLVIS1B, version 1. Testing download...
# Collection title is AfriSAR LVIS L1B Geolocated Return Energy Waveforms V001
# Downloaded file tmp/LVIS1B_Gabon2016_0220_R1808_038024.h5
# File Size is : 950411328 bytes
# Pretty sure tmp/LVIS1B_Gabon2016_0220_R1808_038024.h5 is a valid file.
# Found granules for AFLVIS2, version 1. Testing download...
# Collection title is AfriSAR LVIS L2 Geolocated Surface Elevation Product V001
# Downloaded file tmp/LVIS2_Gabon2016_0220_R1808_038024.TXT
# File Size is : 136401329 bytes
# Pretty sure tmp/LVIS2_Gabon2016_0220_R1808_038024.TXT is a valid file.
# AfriSAR_UAVSAR_Coreg_SLC, version 1 not in NASA's operational CMR.
# AfriSAR_UAVSAR_Geocoded_Covariance, version 1 not in NASA's operational CMR.
# AfriSAR_UAVSAR_Geocoded_SLC, version 1 not in NASA's operational CMR.
# AfriSAR_UAVSAR_Normalization_Area, version 1 not in NASA's operational CMR.
# AfriSAR_UAVSAR_Ungeocoded_Covariance, version 1 not in NASA's operational CMR.
# AfriSAR_UAVSAR_KZ, version 1 not in NASA's operational CMR.
# AfriSAR_UAVSAR_MLC, version 2 not in NASA's operational CMR.
# AfriSAR_UAVSAR_SLC, version 2 not in NASA's operational CMR.
# Found granules for AfriSAR_AGB_Maps_1681, version 1. Testing download...
# Collection title is AfriSAR: Aboveground Biomass for Lope, Mabounie, Mondah, and Rabi Sites, Gabon
# Downloaded file tmp/Rabi_AGB_50m.tif
# File Size is : 14109 bytes
# Pretty sure tmp/Rabi_AGB_50m.tif is a valid file.
# Found granules for AfriSAR_LVIS_Footprint_Cover_1591, version 1. Testing download...
# Collection title is AfriSAR: Canopy Cover and Vertical Profile Metrics Derived from LVIS, Gabon, 2016
# Downloaded file tmp/lvis2_046437_2016022020160220_l2b_paiz_e04326_v0100.csv
# File Size is : 200628421 bytes
# Pretty sure tmp/lvis2_046437_2016022020160220_l2b_paiz_e04326_v0100.csv is a valid file.
# Found granules for Polarimetric_CT_1601, version 1. Testing download...
# Collection title is AfriSAR: Canopy Structure Derived from PolInSAR and Coherence TomoSAR NISAR tools
# Downloaded file tmp/rabi_polinsar_canopy_coherence.tif
# File Size is : 18723052 bytes
# Pretty sure tmp/rabi_polinsar_canopy_coherence.tif is a valid file.
# Found granules for Afrisar_LVIS_Biomass_VProfiles_1775, version 1. Testing download...
# Collection title is AfriSAR: Gridded Forest Biomass and Canopy Metrics Derived from LVIS, Gabon, 2016
# Downloaded file tmp/lvis2_mond_2016022020160308_l3b2_PAI_0-10m_e32732_v0301_r025m.tif
# File Size is : 4709351 bytes
# Pretty sure tmp/lvis2_mond_2016022020160308_l3b2_PAI_0-10m_e32732_v0301_r025m.tif is a valid file.
# Found granules for AfriSAR_Mondah_Field_Data_1580, version 1. Testing download...
# Collection title is AfriSAR: Mondah Forest Tree Species, Biophysical, and Biomass Data, Gabon, 2016
# Downloaded file tmp/Mondah_Field_Data_OrigCoords.csv
# File Size is : 22066 bytes
# Pretty sure tmp/Mondah_Field_Data_OrigCoords.csv is a valid file.
# Found granules for Polarimetric_height_profile_1577, version 1. Testing download...
# Collection title is AfriSAR: Polarimetric Height Profiles by TomoSAR, Lope and Rabi Forests, Gabon, 2016
# Downloaded file tmp/rabi-tomo-capon-hv.h5
# File Size is : 1395705349 bytes
# Pretty sure tmp/rabi-tomo-capon-hv.h5 is a valid file.
# Found granules for PolInSAR_Canopy_Height_1589, version 1. Testing download...
# Collection title is AfriSAR: Rainforest Canopy Height Derived from PolInSAR and Lidar Data, Gabon
# Downloaded file tmp/pongara_canopyheightfusion_uncertainty.tif
# File Size is : 7401664 bytes
# Pretty sure tmp/pongara_canopyheightfusion_uncertainty.tif is a valid file.
# AFRISAR_DLR, version 1 not in NASA's operational CMR.
# AFRISAR_DLR2, version 1 not in NASA's operational CMR.
# AFRISAR_ONERA, version 1 not in NASA's operational CMR.
# ABoVE_UAVSAR_PALSAR, version 1 not in NASA's operational CMR.
# ATL03, version 2 not in NASA's operational CMR.
# ATL03, version 4 not in NASA's operational CMR.
# Found granules for ATL03, version 005. Testing download...
# Collection title is ATLAS/ICESat-2 L2A Global Geolocated Photon Data V005
# Downloaded file tmp/ATL03_20181013235645_02340114_005_01.h5
# File Size is : 409687982 bytes
# Pretty sure tmp/ATL03_20181013235645_02340114_005_01.h5 is a valid file.
# ATL08, version 2 not in NASA's operational CMR.
# ATL08, version 3 not in NASA's operational CMR.
# ATL08, version 4 not in NASA's operational CMR.
# Found granules for ATL08, version 005. Testing download...
# Collection title is ATLAS/ICESat-2 L3A Land and Vegetation Height V005
# Downloaded file tmp/ATL08_20181014001049_02350102_005_01.h5
# File Size is : 7062697 bytes
# Pretty sure tmp/ATL08_20181014001049_02350102_005_01.h5 is a valid file.
# ATL08_ARD-beta, version 1 not in NASA's operational CMR.
# kb_biomass_demo, version 1 not in NASA's operational CMR.
# kb_reprj_biomass, version 1 not in NASA's operational CMR.
# BIOSAR1, version 1 not in NASA's operational CMR.
# BIOSAR2, version 1 not in NASA's operational CMR.
# BIOSAR3, version 1 not in NASA's operational CMR.
# 30mATL08_boreal, version 0 not in NASA's operational CMR.
# EnvStress, version 1 not in NASA's operational CMR.
# ESACCI_Biomass_L4_AGB_V3_100m_2010, version 1 not in NASA's operational CMR.
# ESACCI_Biomass_L4_AGB_V3_100m_2017, version 1 not in NASA's operational CMR.
# ESACCI_Biomass_L4_AGB_V3_100m_2018, version 1 not in NASA's operational CMR.
# GEDI01_B, version 1 not in NASA's operational CMR.
# Found granules for GEDI01_B, version 002. Testing download...
# Collection title is GEDI L1B Geolocated Waveform Data Global Footprint Level V002
# Downloaded file tmp/GEDI01_B_2019108002012_O01959_03_T03909_02_005_01_V002.h5
# File Size is : 423726920 bytes
# Pretty sure tmp/GEDI01_B_2019108002012_O01959_03_T03909_02_005_01_V002.h5 is a valid file.
# GEDI02_A, version 1 not in NASA's operational CMR.
# Found granules for GEDI02_A, version 002. Testing download...
# Collection title is GEDI L2A Elevation and Height Metrics Data Global Footprint Level V002
# Downloaded file tmp/GEDI02_A_2019108002012_O01959_01_T03909_02_003_01_V002.h5
# File Size is : 88117573 bytes
# Pretty sure tmp/GEDI02_A_2019108002012_O01959_01_T03909_02_003_01_V002.h5 is a valid file.
# GEDI02_B, version 1 not in NASA's operational CMR.
# Found granules for GEDI02_B, version 002. Testing download...
# Collection title is GEDI L2B Canopy Cover and Vertical Profile Metrics Data Global Footprint Level V002
# Downloaded file tmp/GEDI02_B_2019108002012_O01959_01_T03909_02_003_01_V002.h5
# File Size is : 17344827 bytes
# Pretty sure tmp/GEDI02_B_2019108002012_O01959_01_T03909_02_003_01_V002.h5 is a valid file.
# Found granules for GEDI_L3_LandSurface_Metrics_V2_1952, version 2. Testing download...
# Collection title is GEDI L3 Gridded Land Surface Metrics, Version 2
# Downloaded file tmp/GEDI03_elev_lowestmode_stddev_2019108_2020287_002_02.tif
# File Size is : 542469324 bytes
# Pretty sure tmp/GEDI03_elev_lowestmode_stddev_2019108_2020287_002_02.tif is a valid file.
# GEDI_L4A_AGB_Density_V2_1986, version 2 not in NASA's operational CMR.
# Found granules for GEDI_L4A_AGB_Density_V2_1_2056, version 2.1. Testing download...
# Collection title is GEDI L4A Footprint Level Aboveground Biomass Density, Version 2.1
# Downloaded file tmp/GEDI04_A_2019107224731_O01958_01_T02638_02_002_02_V002.h5
# File Size is : 86071746 bytes
# Pretty sure tmp/GEDI04_A_2019107224731_O01958_01_T02638_02_002_02_V002.h5 is a valid file.
# Found granules for GEDI_L4B_Gridded_Biomass_2017, version 2. Testing download...
# Collection title is GEDI L4B Gridded Aboveground Biomass Density, Version 2
# Downloaded file tmp/GEDI04_B_MW019MW138_02_002_05_R01000M_PS.tif
# File Size is : 20103343 bytes
# Pretty sure tmp/GEDI04_B_MW019MW138_02_002_05_R01000M_PS.tif is a valid file.
# Global_PALSAR2_PALSAR_FNF, version 1 not in NASA's operational CMR.
# Global_PALSAR2_PALSAR_Mosiac, version 1 not in NASA's operational CMR.
# GEDI_CalVal_Lidar_Data, version 2 not in NASA's operational CMR.
# GEDI_CalVal_Lidar_Data, version 1 not in NASA's operational CMR.
# GEDI_CalVal_Lidar_Data_Compressed, version 2 not in NASA's operational CMR.
# GEDI_CalVal_Field_Data, version 1 not in NASA's operational CMR.
# GEDI_CalVal_Field_Data, version 2 not in NASA's operational CMR.
# Global_Forest_Change_2000-2017, version 1.5 not in NASA's operational CMR.
# GlobCover_05_06, version 2.2 not in NASA's operational CMR.
# GlobCover_09, version 2.3 not in NASA's operational CMR.
# INDREX2, version 1 not in NASA's operational CMR.
# L2_USER_DATA, version 1 not in NASA's operational CMR.
# Landsat7_SurfaceReflectance, version 1 not in NASA's operational CMR.
# Landsat8_SurfaceReflectance, version 1 not in NASA's operational CMR.
# user_shared_landsat8, version 1 not in NASA's operational CMR.
# ShortName_Larc, version Version01 not in NASA's operational CMR.
# Found granules for LVISF1B, version 1. Testing download...
# Collection title is LVIS Facility L1B Geolocated Return Energy Waveforms V001
# Downloaded file tmp/LVISF1B_US2018_1107_R2011_067463.h5
# File Size is : 966015376 bytes
# Pretty sure tmp/LVISF1B_US2018_1107_R2011_067463.h5 is a valid file.
# Found granules for LVISF2, version 1. Testing download...
# Collection title is LVIS Facility L2 Geolocated Surface Elevation and Canopy Height Product V001
# Downloaded file tmp/LVISF2_US2018_1107_R2011_067463.TXT
# File Size is : 128101203 bytes
# Pretty sure tmp/LVISF2_US2018_1107_R2011_067463.TXT is a valid file.
# AfriSAR_KingAir_B200_flight_tracks_Gabon, version 1 not in NASA's operational CMR.
# SRTMGL1_COD, version 1 not in NASA's operational CMR.
# Found granules for SRTMGL1, version 003. Testing download...
# Collection title is NASA Shuttle Radar Topography Mission Global 1 arc second V003
# Downloaded file tmp/S06E072.SRTMGL1.hgt.zip
# File Size is : 29812 bytes
# Pretty sure tmp/S06E072.SRTMGL1.hgt.zip is a valid file.
# nceo_africa_2017, version 1 not in NASA's operational CMR.
# NISAR_RSLC, version 1 not in NASA's operational CMR.
# pongara_test, version 1 not in NASA's operational CMR.
# Found granules for SENTINEL-1A_DP_GRD_HIGH, version 1. Testing download...
# Collection title is Sentinel-1A Dual-pol ground projected high and full resolution images
# Downloaded file tmp/S1A_S3_GRDH_1SDH_20140615T034444_20140615T034512_001055_00107C_8977.zip
# File Size is : 245899817 bytes
# Pretty sure tmp/S1A_S3_GRDH_1SDH_20140615T034444_20140615T034512_001055_00107C_8977.zip is a valid file.
# Found granules for SENTINEL-1A_SLC, version 1. Testing download...
# Collection title is Sentinel-1A slant-range product
# Downloaded file tmp/S1A_S3_SLC__1SDH_20140615T034444_20140615T034512_001055_00107C_16F1.zip
# File Size is : 4182979680 bytes
# Pretty sure tmp/S1A_S3_SLC__1SDH_20140615T034444_20140615T034512_001055_00107C_16F1.zip is a valid file.
# Found granules for SENTINEL-1B_DP_GRD_HIGH, version 1. Testing download...
# Collection title is Sentinel-1B Dual-pol ground projected high and full resolution images, Texas/Mexico and Peru, September 2016-July 2019
# Downloaded file tmp/S1B_IW_GRDH_1SDV_20160926T003306_20160926T003335_002233_003C11_A052.zip
# File Size is : 1022934971 bytes
# Pretty sure tmp/S1B_IW_GRDH_1SDV_20160926T003306_20160926T003335_002233_003C11_A052.zip is a valid file.
# test_collection_feb23, version 1 not in NASA's operational CMR.
# TROPISAR, version 1 not in NASA's operational CMR.
# USER_SHARED_EX_1210, version 1 not in NASA's operational CMR.
# Not in CMR:
# ['AfriSAR UAVSAR Coregistered SLCs Generated Using NISAR Tools', 'AfriSAR_UAVSAR_Coreg_SLC', '1']
# ['AfriSAR UAVSAR Geocoded Covariance Matrix product Generated Using NISAR Tools', 'AfriSAR_UAVSAR_Geocoded_Covariance', '1']
# ['AfriSAR UAVSAR Geocoded SLCs Generated Using NISAR Tools', 'AfriSAR_UAVSAR_Geocoded_SLC', '1']
# ['AfriSAR UAVSAR Normalization Area Generated Using NISAR Tools', 'AfriSAR_UAVSAR_Normalization_Area', '1']
# ['AfriSAR UAVSAR Ungeocoded Covariance Matrix product Generated Using NISAR Tools', 'AfriSAR_UAVSAR_Ungeocoded_Covariance', '1']
# ['AfriSAR UAVSAR Vertical Wavenumber (KZ) Generated Using NISAR Tools', 'AfriSAR_UAVSAR_KZ', '1']
# ['AfriSAR Uninhabited Aerial Vehicle Synthetic Aperture Radar Multi Look Cross Product, Pongara National Forest Gabon, 27 February 2016', 'AfriSAR_UAVSAR_MLC', '2']
# ['AfriSAR Uninhabited Aerial Vehicle Synthetic Aperture Radar Single Look Complex, Pongara National Forest Gabon, 27 February 2016', 'AfriSAR_UAVSAR_SLC', '2']
# ['AFRISAR_DLR', 'AFRISAR_DLR', '1']
# ['AFRISAR_DLR2', 'AFRISAR_DLR2', '1']
# ['AFRISAR_ONERA', 'AFRISAR_ONERA', '1']
# ['Arctic-Boreal Vulnerability Experiment Uninhabited Aerial Vehicle Synthetic Aperture Radar Polarimetric SAR', 'ABoVE_UAVSAR_PALSAR', '1']
# ['ATLAS/ICESat-2 L2A Global Geolocated Photon Data V002, October 2018-September 2019', 'ATL03', '2']
# ['ATLAS/ICESat-2 L2A Global Geolocated Photon Data V004', 'ATL03', '4']
# ['ATLAS/ICESat-2 L3A Land and Vegetation Height V002, October 2018-June 2019', 'ATL08', '2']
# ['ATLAS/ICESat-2 L3A Land and Vegetation Height V003', 'ATL08', '3']
# ['ATLAS/ICESat-2 L3A Land and Vegetation Height V004', 'ATL08', '4']
# ['ATLAS/ICESat-2 Land and Vegetation Height V003 ARD V001 - beta', 'ATL08_ARD-beta', '1']
# ['Biomass Map (Demo)', 'kb_biomass_demo', '1']
# ['Biomass Map Reprojected (Demo)', 'kb_reprj_biomass', '1']
# ['BIOSAR1', 'BIOSAR1', '1']
# ['BIOSAR2', 'BIOSAR2', '1']
# ['BIOSAR3', 'BIOSAR3', '1']
# ['Boreal 30m ATL08 - test', '30mATL08_boreal', '0']
# ['Environmental Stress Factor for Diameter-Height Tree Allometry', 'EnvStress', '1']
# ['ESACCI_Biomass_L4_AGB_V3_100m_2010', 'ESACCI_Biomass_L4_AGB_V3_100m_2010', '1']
# ['ESACCI_Biomass_L4_AGB_V3_100m_2017', 'ESACCI_Biomass_L4_AGB_V3_100m_2017', '1']
# ['ESACCI_Biomass_L4_AGB_V3_100m_2018', 'ESACCI_Biomass_L4_AGB_V3_100m_2018', '1']
# ['GEDI L1B Geolocated Waveform Data Global Footprint Level V001, April 2019-July 2019', 'GEDI01_B', '1']
# ['GEDI L2A Elevation and Height Metrics Data Global Footprint Level V001, April 2019-July 2019', 'GEDI02_A', '1']
# ['GEDI L2B Canopy Cover and Vertical Profile Metrics Data Global Footprint Level V001, April 2019-August 2019', 'GEDI02_B', '1']
# ['GEDI L4A Footprint Level Aboveground Biomass Density, Version 2', 'GEDI_L4A_AGB_Density_V2_1986', '2']
# ['Global 25m Resolution PALSAR-2/PALSAR Forest/Non-Forest Map', 'Global_PALSAR2_PALSAR_FNF', '1']
# ['Global 25m Resolution PALSAR-2/PALSAR Mosaic', 'Global_PALSAR2_PALSAR_Mosiac', '1']
# ['Global Ecosystem Dynamics Investigation (GEDI) Calibration/Validation Airborne Lidar Dataset', 'GEDI_CalVal_Lidar_Data', '2']
# ['Global Ecosystem Dynamics Investigation (GEDI) Calibration/Validation Airborne Lidar Dataset', 'GEDI_CalVal_Lidar_Data', '1']
# ['Global Ecosystem Dynamics Investigation (GEDI) Calibration/Validation Airborne Lidar Dataset (Compressed)', 'GEDI_CalVal_Lidar_Data_Compressed', '2']
# ['Global Ecosystem Dynamics Investigation (GEDI) Calibration/Validation Field Survey Dataset', 'GEDI_CalVal_Field_Data', '1']
# ['Global Ecosystem Dynamics Investigation (GEDI) Calibration/Validation Field Survey Dataset v2', 'GEDI_CalVal_Field_Data', '2']
# ['Global Forest Change 2000-2017', 'Global_Forest_Change_2000-2017', '1.5']
# ['GlobCover Global Land Cover Product (2005-06)', 'GlobCover_05_06', '2.2']
# ['GlobCover Global Land Cover Product (2009)', 'GlobCover_09', '2.3']
# ['INDREX2', 'INDREX2', '1']
# ['L2_USER_DATA', 'L2_USER_DATA', '1']
# ['Landsat 7 Enhanced Thematic Mapper Plus (ETM+) Surface Reflectance Analysis Ready Data (ARD) V1, Equatorial Western Africa, July 1999-April 2019', 'Landsat7_SurfaceReflectance', '1']
# ['Landsat 8 Operational Land Imager (OLI) Surface Reflectance Analysis Ready Data (ARD) V1, Peru and Equatorial Western Africa, April 2013-January 2020', 'Landsat8_SurfaceReflectance', '1']
# ['Landsat8 Covariates', 'user_shared_landsat8', '1']
# ['LarcDatasetId', 'ShortName_Larc', 'Version01']
# ['NASA Langley KingAir B-200 Flight Tracks for Gabon, Africa 2016', 'AfriSAR_KingAir_B200_flight_tracks_Gabon', '1']
# ['NASA Shuttle Radar Topography Mission Global 1 arc second COD V001', 'SRTMGL1_COD', '1']
# ['NCEO Africa Aboveground Woody Biomass 2017', 'nceo_africa_2017', '1']
# ['NISAR Range Doppler Single Look Complex Version 001', 'NISAR_RSLC', '1']
# ['Pongara Range Slope Copy', 'pongara_test', '1']
# ['Testing Collection Feb 23', 'test_collection_feb23', '1']
# ['TROPISAR', 'TROPISAR', '1']
# ['User Shared Data Example Dec 10', 'USER_SHARED_EX_1210', '1']
# Can access:
# ['ABoVE LVIS L1B Geolocated Return Energy Waveforms V001', 'ABLVIS1B', '1']
# ['ABoVE LVIS L2 Geolocated Surface Elevation Product V001', 'ABLVIS2', '1']
# ['Advance Land Observing Satellite Phased Array type L-band Synthetic Aperture Radar Radiometric Terrain-Corrected High Resolution products, Equatorial Western Africa, May 2006-March 2011', 'ALOS_PSR_RTC_HIGH', '1']
# ['Advanced Land Observation Satellite (ALOS) Phased Array L-band Synthetic Aperture Radar, Equatorial Western Africa, May 2006-March 2011', 'ALOS_PSR_L1.5', '1']
# ['AfriSAR LVIS L1B Geolocated Return Energy Waveforms V001', 'AFLVIS1B', '1']
# ['AfriSAR LVIS L2 Geolocated Surface Elevation Product V001', 'AFLVIS2', '1']
# ['AfriSAR: Aboveground Biomass for Lope, Mabounie, Mondah, and Rabi Sites, Gabon', 'AfriSAR_AGB_Maps_1681', '1']
# ['AfriSAR: Canopy Cover and Vertical Profile Metrics Derived from LVIS, Gabon, 2016', 'AfriSAR_LVIS_Footprint_Cover_1591', '1']
# ['AfriSAR: Canopy Structure Derived from PolInSAR and Coherence TomoSAR NISAR tools', 'Polarimetric_CT_1601', '1']
# ['AfriSAR: Gridded Forest Biomass and Canopy Metrics Derived from LVIS, Gabon, 2016', 'Afrisar_LVIS_Biomass_VProfiles_1775', '1']
# ['AfriSAR: Mondah Forest Tree Species, Biophysical, and Biomass Data, Gabon, 2016', 'AfriSAR_Mondah_Field_Data_1580', '1']
# ['AfriSAR: Polarimetric Height Profiles by TomoSAR, Lope and Rabi Forests, Gabon, 2016', 'Polarimetric_height_profile_1577', '1']
# ['AfriSAR: Rainforest Canopy Height Derived from PolInSAR and Lidar Data, Gabon', 'PolInSAR_Canopy_Height_1589', '1']
# ['ATLAS/ICESat-2 L2A Global Geolocated Photon Data V005', 'ATL03', '005']
# ['ATLAS/ICESat-2 L3A Land and Vegetation Height V005', 'ATL08', '005']
# ['GEDI L1B Geolocated Waveform Data Global Footprint Level V002', 'GEDI01_B', '002']
# ['GEDI L2A Elevation and Height Metrics Data Global Footprint Level V002', 'GEDI02_A', '002']
# ['GEDI L2B Canopy Cover and Vertical Profile Metrics Data Global Footprint Level V002', 'GEDI02_B', '002']
# ['GEDI L3 Gridded Land Surface Metrics, Version 2', 'GEDI_L3_LandSurface_Metrics_V2_1952', '2']
# ['GEDI L4A Footprint Level Aboveground Biomass Density, Version 2.1', 'GEDI_L4A_AGB_Density_V2_1_2056', '2.1']
# ['GEDI L4B Gridded Aboveground Biomass Density, Version 2', 'GEDI_L4B_Gridded_Biomass_2017', '2']
# ['LVIS Facility L1B Geolocated Return Energy Waveforms V001', 'LVISF1B', '1']
# ['LVIS Facility L2 Geolocated Surface Elevation and Canopy Height Product V001', 'LVISF2', '1']
# ['NASA Shuttle Radar Topography Mission Global 1 arc second V003', 'SRTMGL1', '003']
# ['Sentinel-1A Dual-pol ground projected high and full resolution images', 'SENTINEL-1A_DP_GRD_HIGH', '1']
# ['Sentinel-1A slant-range product', 'SENTINEL-1A_SLC', '1']
# ['Sentinel-1B Dual-pol ground projected high and full resolution images, Texas/Mexico and Peru, September 2016-July 2019', 'SENTINEL-1B_DP_GRD_HIGH', '1']
# Cannot access:
