# %%
# /// script
# requires-python = ">=3.13"
# dependencies = [
#     "aiobotocore",
#     "boto3",
#     "stactools-icesat2-boreal",
#     "obstore",
#     "pandas",
#     "pystac",
#     "pystac-client",
#     "stac-pydantic",
#     "tqdm",
#     "geopandas",
# ]
#
# [tool.uv.sources]
# stactools-icesat2-boreal = { git = "https://github.com/MAAP-Project/icesat2-boreal-stac", rev = "0.3.1" }
# ///

# %% [markdown]
# # Publish icesat2-boreal-v3.0-agb/ht collections
#
# **Author:** Henry Rodman
#
# **Date:** 2025-07-09
#
# This notebook uses the `icesat2-boreal-v3.0` collections to demonstrate how to publish new collections to the MAAP STAC using the SNS-based STAC metadata generation and ingestion infrastructure.
#
# MAAP uses an asynchronous, event-driven workflow for loading metadata into the pgstac database. The components of this system are as follows:
# - `StacItemLoader`: SNS topic + SQS queue + Lambda function for loading STAC metadata into pgstac
#   - the SNS topic accepts either STAC items/collections or S3 event notifications for STAC json files
#   - collections and items are loaded into pgstac in batches from the SQS queue by the Lambda function
#   - for more details, see the [`StacLoader` documentation in eoapi-cdk](https://developmentseed.org/eoapi-cdk/#stacloader-)
# - `StactoolsItemGenerator`: SNS topic + SQS queue + Lambda function for using stactools packages to generate STAC items
#   - the SNS topic expects a message with the stactools package source (e.g. pypi package name, git repo, etc) and the arguments for the `create-item` CLI command
#   - the Lambda function uses `uvx` to install the required packages and run the create-item command on-the-fly
#   - resulting STAC items are posted to the `StacLoader` SNS topic
#   - for more details, see the [`StactoolsItemGenerator` documentation in eoapi-cdk](https://developmentseed.org/eoapi-cdk/#stactoolsitemgenerator-)
#
# The operational workflow for using this infrastructure to publish a new collection to the MAAP STAC is as follows:
#
# 1. Copy the assets to the `s3://nasa-maap-data-store` S3 bucket
# 2. Generate the collection JSON and post it to the `StacLoader` SNS topic
# 3. Generate STAC items using the `StactoolsItemGenerator` infrastructure
#     - create list of stactools-uvx messages, post them to the SNS topic
#     - the Lambda function will generate the STAC items and post them to the `StacLoader` SNS topic
#
# This notebook is the first end-to-end test of this process for MAAP!

# %%
import asyncio
import io
import json
import time
from pathlib import Path
from typing import Any, Dict, List, Tuple

import boto3
import geopandas as gpd
import obstore as obs
import pandas as pd
import pystac_client
from aiobotocore.session import get_session
from obstore.store import S3Store
from stac_pydantic import Collection
from botocore.exceptions import ClientError
from tqdm.asyncio import tqdm

from stactools.icesat2_boreal.stac import create_collection, create_item
from stactools.icesat2_boreal.constants import Variable, TILE_GPKG_BUCKET, TILE_GPKG_KEY

STAC_LOADER_SNS_TOPIC_ARN = "arn:aws:sns:us-west-2:916098889494:MAAP-STAC-dev-pgSTAC-stacitemloaderTopicD9D06088-m0iaNFNtnXUP"
STACTOOLS_ITEM_GENERATOR_SNS_TOPIC_ARN = "arn:aws:sns:us-west-2:916098889494:MAAP-STAC-dev-pgSTAC-stactoolsitemgeneratorTopic79301C28-4oAhGx3hL3bM"

MAAP_OPS_BUCKET = "maap-ops-workspace"
ASSET_DEST_BUCKET = "nasa-maap-data-store"

ICESAT2_BOREAL_PREFIX = "file-staging/nasa-map/icesat2-boreal-v3.0"
DEST_KEY_FMT = ICESAT2_BOREAL_PREFIX + "/{variable}/{tile:07d}/{name}"

AWS_REGION = "us-west-2"

agb_inventory_key = "shared/montesano/DPS_tile_lists/BOREAL_MAP/v3.0.0/AGB_H30_2020/full_run/AGB_tindex_master.csv"
ht_inventory_key = "shared/montesano/DPS_tile_lists/BOREAL_MAP/v3.0.0/Ht_H30_2020/full_run/HT_tindex_master.csv"
full_tile_gpkg_key = "shared/montesano/databank/boreal_tiles_v004.gpkg"

sns_client = boto3.client("sns")
s3_client = boto3.client("s3")
full_tile_gdf = gpd.read_file(f"s3://{MAAP_OPS_BUCKET}/{full_tile_gpkg_key}")

# %% [markdown]
# Since we have to process two collections, I am defining a few functions to reduce duplicated code.

# %%
async def copy_s3_keys(
    source_bucket_name: str,
    destination_bucket_name: str,
    key_mapping_tuples: List[Tuple[str, str]],
    aws_region: str = AWS_REGION,
    max_concurrent_copies: int = 50,
):
    """
    Copies a specific set of S3 objects from one bucket to another asynchronously,
    allowing renaming in the destination, without local download, and displays
    progress using tqdm.

    Args:
        source_bucket_name (str): The name of the source S3 bucket.
        destination_bucket_name (str): The name of the destination S3 bucket.
        key_mapping_tuples (list): A list of tuples, where each tuple is
                                   (source_key, destination_key).
                                   source_key: The key of the object in the source bucket.
                                   destination_key: The desired key for the object
                                                    in the destination bucket.
        aws_region (str): The AWS region of the buckets (e.g., "us-east-1").
        max_concurrent_copies (int): The maximum number of S3 copy operations
                                     to run concurrently. Adjust based on your
                                     AWS account limits and network conditions.
    """
    session = get_session()

    # Create an S3 client asynchronously within an async context manager
    async with session.create_client("s3", region_name=aws_region) as s3_client:
        # Use an asyncio Semaphore to limit the number of concurrent tasks
        # This prevents overwhelming S3 or hitting your connection limits
        semaphore = asyncio.Semaphore(max_concurrent_copies)

        async def _copy_single_object(src_key, dest_key):
            """Helper async function to copy a single S3 object."""
            async with semaphore:
                try:
                    copy_source = {"Bucket": source_bucket_name, "Key": src_key}
                    await s3_client.copy_object(
                        CopySource=copy_source,
                        Bucket=destination_bucket_name,
                        Key=dest_key,
                    )
                    return True
                except ClientError as e:
                    if e.response["Error"]["Code"] == "NoSuchKey":
                        tqdm.write(
                            f"Error: Source key '{src_key}' not found in bucket '{source_bucket_name}'."
                        )
                    else:
                        tqdm.write(f'Error copying "{src_key}" to "{dest_key}": {e}')
                    return False
                except Exception as e:
                    tqdm.write(
                        f"An unexpected error occurred while copying '{src_key}' to '{dest_key}': {e}"
                    )
                    return False

        tasks = []
        for src_key, dest_key in key_mapping_tuples:
            tasks.append(_copy_single_object(src_key, dest_key))

        results = await tqdm.gather(*tasks, desc="Copying S3 Objects", unit="file")

    successful_copies = results.count(True)
    failed_copies = results.count(False)
    if failed_copies > 0:
        print(
            f"\nCompleted S3 copy operation. {successful_copies} files copied successfully, {failed_copies} failed."
        )
    else:
        print(
            f"\nCompleted S3 copy operation. All {successful_copies} files copied successfully."
        )


def read_inventory(inventory_key: str) -> pd.DataFrame:
    """Reads the inventory file with S3 paths to the COG files that should be cataloged.
    The inventory file was roduced by Paul Montesano after all of the DPS jobs were completed.

    Returns: a pandas DataFrame with the inventory information
    """
    maap_ops_store = S3Store(MAAP_OPS_BUCKET, region=AWS_REGION)

    return pd.read_csv(io.BytesIO(obs.get(maap_ops_store, inventory_key).bytes()))


def generate_key_mappings(
    inventory: pd.DataFrame,
    variable: str,
) -> Tuple[List[Tuple[str, str]], ...]:
    """Generates source/destination key pairs for the COG and CSV assets to be used for
    copying the files from the maap-ops-workspace bucket to the canonical bucket for MAAP
    products
    """
    cog_key_mappings = [
        (
            row["s3_path"].replace(f"s3://{MAAP_OPS_BUCKET}/", ""),
            DEST_KEY_FMT.format(
                variable=variable, tile=row["tile_num"], name=Path(row["s3_path"]).name
            ),
        )
        for _, row in inventory.iterrows()
    ]

    csv_key_mappings = [
        (
            row["s3_path"]
            .replace(f"s3://{MAAP_OPS_BUCKET}/", "")
            .replace(".tif", "_train_data.csv"),
            DEST_KEY_FMT.format(
                variable=variable,
                tile=row["tile_num"],
                name=Path(row["s3_path"]).name.replace(".tif", "_train_data.csv"),
            ),
        )
        for _, row in inventory.iterrows()
    ]

    return cog_key_mappings, csv_key_mappings


def generate_asset_keys(
    cog_key_mappings: List[Tuple[str, str]],
    csv_key_mappings: List[Tuple[str, str]],
    bucket: str,
) -> List[Tuple[str, str]]:
    """Generates tuples of (cog, csv) S3 keys to be used as asset hrefs in the STAC items"""
    return [
        (f"s3://{bucket}/{cog_key}", f"s3://{bucket}/{csv_key}")
        for (_, cog_key), (_, csv_key) in zip(cog_key_mappings, csv_key_mappings)
    ]


def generate_stactools_messages(
    asset_keys: List[Tuple[str, str]],
    collection_id: str,
) -> List[Dict[str, Any]]:
    """Generates the StactoolsItemGenerator messages

    Includes the stactools package source (icesat2-boreal-stac repo in github), the
    CLI group name (icesat2boreal), and the positional arguments required for the
    create-item command (cog_source, csv_source)
    """
    return [
        {
            "package_name": "git+https://github.com/MAAP-Project/icesat2-boreal-stac@0.3.1",
            "group_name": "icesat2boreal",
            "create_item_args": [
                cog_key,
                csv_key,
            ],
            "collection_id": collection_id,
        }
        for cog_key, csv_key in asset_keys
    ]


def publish_stactools_messages(messages: List[Dict[str, Any]]) -> None:
    """Loop to publish StactoolsItemGenerator messages in batches of 10"""
    batch_size = 10

    for i in range(0, len(messages), batch_size):
        batch = messages[i : i + batch_size]

        batch_entries = []
        for j, message in enumerate(batch):
            unique_batch_id = f"msg-{i + j:04d}"

            json_message_string = json.dumps(message)

            entry = {
                "Id": unique_batch_id,
                "Message": json_message_string,
            }
            batch_entries.append(entry)

        print(
            f"\n--- Processing batch {int(i / batch_size) + 1} (messages {i} to {i + batch_size - 1}) ---"
        )

        try:
            # Publish the batch to SNS
            response = sns_client.publish_batch(
                TopicArn=STACTOOLS_ITEM_GENERATOR_SNS_TOPIC_ARN,
                PublishBatchRequestEntries=batch_entries,
            )

            # Check the response for successful and failed messages
            if "Successful" in response and response["Successful"]:
                print(
                    f"  Successfully published {len(response['Successful'])} messages in this batch."
                )
            if "Failed" in response and response["Failed"]:
                print(
                    f"  Failed to publish {len(response['Failed'])} messages in this batch:"
                )
                for failure in response["Failed"]:
                    print(
                        f"    - ID: {failure['Id']}, Code: {failure.get('Code', 'N/A')}, Message: {failure.get('Message', 'N/A')}"
                    )

        except Exception as e:
            print(f"  An error occurred while publishing this batch: {e}")

        # Small delay to avoid hitting API rate limits
        time.sleep(0.1)

    print("\n--- All batches processed ---")

# %% [markdown]
# ## Tile geopackage
#
# We need to upload a copy of the tile geometry geopackage with the exact tiles that are included in this collection.

# %%
agb_inventory = read_inventory(agb_inventory_key)
ht_inventory = read_inventory(ht_inventory_key)

tile_nums = set(agb_inventory["tile_num"].tolist() + ht_inventory["tile_num"].tolist())

public_tile_gdf = full_tile_gdf.loc[
    full_tile_gdf["tile_num"].isin(tile_nums), ["tile_num", "geometry"]
]

gpkg = "/tmp/boreal_tiles_v004.gpkg"
public_tile_gdf.to_file(gpkg)

# %%
s3_client.upload_file(
    gpkg,
    TILE_GPKG_BUCKET,
    TILE_GPKG_KEY,
    ExtraArgs={"ACL": "bucket-owner-full-control"},
)

# %% [markdown]
# ## AGB
#
# ### Collection
# Start by creating the collection and validating it using `pystac` and `stac-pydantic`

# %%
agb_collection = create_collection(Variable.AGB)

# validate
_ = agb_collection.validate()  # pystac
_ = Collection(**agb_collection.to_dict())  # stac-pydantic

print(json.dumps(agb_collection.to_dict(), indent=2))
# Out:
# {
#   "type": "Collection",
#   "id": "icesat2-boreal-v3.0-agb",
#   "stac_version": "1.1.0",
#   "description": "This dataset provides predictions of woody aboveground biomass density (AGBD) and vegetation height for high northern latitude forests at 30 m spatial resolution for the year 2020, accounting for >30% of global forest area.\n\nMaps of woody AGBD and height are essential for understanding patterns of forest structure, including the mass of forest vegetation, its carbon content, and its vertical and horizontal arrangement across managed and unmanaged landscapes. These maps are optimized to visualize these patterns, monitor forest conditions, and manage forest carbon stocks and their changes. The information contained in these maps provides insights into the current conditions and shifts in a global biome that is shaped by natural processes that play out across decades to millennia, as well as human decisions, and whose status and functioning affects wildlife, the climate, economies, and the wellbeing of public and private sector stakeholders both within and outside of the north.\n\nThese maps are built with state-of-the-art earth observation datasets collected from space, including lidar observations from NASA\u2019s ICESat-2 and imagery from NASA\u2019s Harmonized Landsat/Sentinel-2 project. They are designed for circumpolar boreal-wide mapping from local to global scales and provide the northern component of global forest structure estimates, to which complementary estimates from NASA's Global Ecosystem Dynamics Investigation (GEDI) mission contribute temperate and tropical portions. The AGBD and height predictions cover the extent of high latitude boreal forests and shrublands, and while they extend southward outside the boreal domain nominally to ~50\u00b0N they are intended to contribute to global estimates northward from 51.6\u00b0N.\n\nThe compilation of these maps is a final value-added step made possible by decades of investment coupled with world-class expertise from the US Government into engineering, space, and earth science. With this long-term investment, NASA and its federal (USGS, NOAA), international, and private sector partners have conceived of, tested, built, launched, collected and processed data from, and maintained a constellation of, earth observation satellites that provide the fundamental measurements used to build these maps.\n\nThese maps are compiled on a platform built for geoscience algorithm development and data processing that uses Amazon Web Services. This platform (the Multi-mission Algorithm and Analysis Platform; www.maap-project.org) is the result of an international partnership between NASA and the European Space Agency to promote and support science that is accessible, reproducible, and well-documented. This work is the result of a collaboration of a team of scientists and engineers from the University of Maryland-College Park, NASA Goddard Space Flight Center, the University of Texas-Austin, NASA Jet Propulsion Lab, and Development Seed. The primary funding source for this work came through NASA Terrestrial Ecology Program grants associated with NASA\u2019s decade-long Arctic/Boreal Vulnerability Experiment (http://above.nasa.gov)",
#   "links": [
#     {
#       "rel": "about",
#       "href": "https://github.com/lauraduncanson/icesat2_boreal",
#       "type": "text/html",
#       "title": "icesat2_boreal GitHub repository"
#     },
#     {
#       "rel": "predecessor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal",
#       "title": "Previous version (v1.0)"
#     },
#     {
#       "rel": "predecessor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-agb",
#       "title": "Previous version (v2.1)"
#     }
#   ],
#   "stac_extensions": [
#     "https://stac-extensions.github.io/version/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/processing/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/render/v2.0.0/schema.json",
#     "https://stac-extensions.github.io/scientific/v1.0.0/schema.json"
#   ],
#   "item_assets": {
#     "cog": {
#       "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#       "roles": [
#         "data"
#       ],
#       "gsd": 30,
#       "processing:level": "L4",
#       "bands": [
#         {
#           "name": "predicted",
#           "sampling": "area",
#           "nodata": "nan",
#           "scale": 1,
#           "offset": 0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "Mg ha-1"
#         },
#         {
#           "name": "sd",
#           "sampling": "area",
#           "nodata": "nan",
#           "scale": 1,
#           "offset": 0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "Mg ha-1"
#         }
#       ],
#       "title": "Gridded predictions of aboveground biomass (Mg/ha)",
#       "description": "Gridded predictions of aboveground biomass (Mg/ha)"
#     },
#     "training_data_csv": {
#       "type": "text/csv",
#       "roles": [
#         "data"
#       ],
#       "title": "Tabular training data",
#       "description": "Tabular training data with latitude, longitude, and biomass observations"
#     }
#   },
#   "version": "v3.0",
#   "deprecated": false,
#   "renders": {
#     "agb_viridis": {
#       "assets": [
#         "cog"
#       ],
#       "title": "Aboveground biomass (Mg/ha)",
#       "expression": "cog_b1",
#       "rescale": [
#         [
#           0,
#           125
#         ]
#       ],
#       "colormap_name": "viridis",
#       "minmax_zoom": [
#         6,
#         18
#       ]
#     },
#     "agb_gist_earth_r": {
#       "assets": [
#         "cog"
#       ],
#       "title": "Aboveground biomass (Mg/ha)",
#       "expression": "cog_b1",
#       "rescale": [
#         [
#           0,
#           400
#         ]
#       ],
#       "colormap_name": "gist_earth_r",
#       "color_formula": "gamma r 1.05",
#       "minmax_zoom": [
#         6,
#         18
#       ]
#     }
#   },
#   "sci:citation": "Duncanson, L., P.M. Montesano, A. Neuenschwander, A. Zarringhalam, N. Thomas, A. Mandel, D. Minor, E. Guenther, S. Hancock, T. Feng, A. Barciauskas, G.W. Chang, S. Shah, and B.P. Satorius. Circumpolar boreal aboveground biomass mapping with ICESat-2. (in prep.)",
#   "title": "Circumpolar boreal forest structure from ICESat-2 & HLS (2020 v3.0): 30m aboveground woody biomass density",
#   "extent": {
#     "spatial": {
#       "bbox": [
#         [
#           -180,
#           51.6,
#           180,
#           78
#         ]
#       ]
#     },
#     "temporal": {
#       "interval": [
#         [
#           "2020-01-01T00:00:00Z",
#           "2020-12-31T23:59:59Z"
#         ]
#       ]
#     }
#   },
#   "license": "CC-BY",
#   "providers": [
#     {
#       "name": "MAAP",
#       "description": "The MAAP platform is designed to combine data, algorithms, and computational abilities for the processing and sharing of data related to NASA\u2019s GEDI, ESA\u2019s BIOMASS, and NASA/ISRO\u2019s NISAR missions",
#       "roles": [
#         "processor",
#         "producer",
#         "host"
#       ],
#       "url": "https://maap-project.org",
#       "processing:level": "L4"
#     }
#   ],
#   "summaries": {
#     "platform": [
#       "LANDSAT-8",
#       "LANDSAT-9",
#       "SENTINEL-2A",
#       "SENTINEL-2B",
#       "ICESat-2"
#     ],
#     "instruments": [
#       "Advanced Topographic Laser Altimeter System",
#       "Operational Land Imager",
#       "Operational Land Imager 2",
#       "Sentinel-2 Multispectral Imager"
#     ],
#     "mission": [
#       "ABoVE"
#     ],
#     "processing:level": [
#       "L4"
#     ],
#     "gsd": {
#       "minimum": 30,
#       "maximum": 30
#     }
#   },
#   "assets": {
#     "tiles": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/boreal_tiles_v004.gpkg",
#       "type": "application/geopackage+sqlite3",
#       "title": "Processing tiles",
#       "description": "90 km tile geometries for processing AGB predictions",
#       "roles": [
#         "metadata"
#       ]
#     }
#   }
# }

# %% [markdown]
# Post the valid collection JSON to the `StacLoader` SNS topic

# %%
# post collection to StacLoader
response = sns_client.publish(
    TopicArn=STAC_LOADER_SNS_TOPIC_ARN, Message=json.dumps(agb_collection.to_dict())
)
print(response)
# Out:
# {'MessageId': '3f1cfeed-6f4d-595c-b028-9e0134d0733b', 'ResponseMetadata': {'RequestId': '56cfce06-927d-50f7-8b5b-aeeac9e0ba90', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '56cfce06-927d-50f7-8b5b-aeeac9e0ba90', 'date': 'Sat, 12 Jul 2025 12:47:25 GMT', 'content-type': 'text/xml', 'content-length': '294', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}

# %% [markdown]
# ### Items
#
# Read the inventory csv that Paul produced for the AGB predictions

# %%
agb_inventory = read_inventory(agb_inventory_key)

print(agb_inventory.shape)
agb_inventory.head()
# Out:
# (4950, 5)
#    index                                            s3_path  \
# 0      0  s3://maap-ops-workspace/aliz237/dps_output/run...
# 1      1  s3://maap-ops-workspace/aliz237/dps_output/run...
# 2      2  s3://maap-ops-workspace/aliz237/dps_output/run...
# 3      3  s3://maap-ops-workspace/aliz237/dps_output/run...
# 4      4  s3://maap-ops-workspace/aliz237/dps_output/run...
#
#                                           local_path  \
# 0  /projects/my-private-bucket/dps_output/run_bor...
# 1  /projects/my-private-bucket/dps_output/run_bor...
# 2  /projects/my-private-bucket/dps_output/run_bor...
# 3  /projects/my-private-bucket/dps_output/run_bor...
# 4  /projects/my-private-bucket/dps_output/run_bor...
#
#                                              file  tile_num
# 0  boreal_agb_2020_202506061749236725_0003543.tif      3543
# 1  boreal_agb_2020_202506061749236739_0003637.tif      3637
# 2  boreal_agb_2020_202506061749236743_0003732.tif      3732
# 3  boreal_agb_2020_202506061749236786_0003731.tif      3731
# 4  boreal_agb_2020_202506061749236758_0003638.tif      3638

# %% [markdown]
# Prepare a list of source/destination S3 key paths so we can copy the data out of `maap-ops-workspace` into the 'public' bucket (`nasa-maap-data-store`).

# %%
agb_cog_key_mappings, agb_csv_key_mappings = generate_key_mappings(agb_inventory, "agb")
print(agb_cog_key_mappings[0])
print(agb_csv_key_mappings[0])
# Out:
# ('aliz237/dps_output/run_boreal_biomass_map/v3.0.0/AGB_H30_2020/full_run/2025/06/06/12/29/57/749959/boreal_agb_2020_202506061749236725_0003543.tif', 'file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543.tif')
# ('aliz237/dps_output/run_boreal_biomass_map/v3.0.0/AGB_H30_2020/full_run/2025/06/06/12/29/57/749959/boreal_agb_2020_202506061749236725_0003543_train_data.csv', 'file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543_train_data.csv')

# %% [markdown]
# Copy the files over to the destination bucket

# %%
await copy_s3_keys(
    source_bucket_name=MAAP_OPS_BUCKET,
    destination_bucket_name=ASSET_DEST_BUCKET,
    key_mapping_tuples=agb_cog_key_mappings + agb_csv_key_mappings,
    aws_region=AWS_REGION,
)
# Out:
# Copying S3 Objects: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9900/9900 [26:53<00:00,  6.13file/s]
# Completed S3 copy operation. All 9900 files copied successfully.

# %% [markdown]
# Now that the assets have been copied to the public bucket, generate the hrefs for the assets with the full `s3://{bucket}` prefix.

# %%
agb_asset_keys = generate_asset_keys(
    agb_cog_key_mappings, agb_csv_key_mappings, bucket=ASSET_DEST_BUCKET
)
agb_asset_keys[0]
# Out:
# ('s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543.tif',
#  's3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543_train_data.csv')

# %% [markdown]
# Try creating a STAC item with those asset hrefs:

# %%
test_item = create_item(*agb_asset_keys[0])
print(json.dumps(test_item.to_dict(), indent=2))
# Out:
# {
#   "type": "Feature",
#   "stac_version": "1.1.0",
#   "stac_extensions": [
#     "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#   ],
#   "id": "boreal_agb_2020_202506061749236725_0003543",
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -167.7268555007834,
#           65.958744412074
#         ],
#         [
#           -165.7687890462486,
#           65.80241344492612
#         ],
#         [
#           -165.33767128760388,
#           66.58197078937214
#         ],
#         [
#           -167.35203068347897,
#           66.74321074546818
#         ],
#         [
#           -167.7268555007834,
#           65.958744412074
#         ]
#       ]
#     ]
#   },
#   "bbox": [
#     -167.7268555007834,
#     65.80241344492612,
#     -165.33767128760388,
#     66.74321074546818
#   ],
#   "properties": {
#     "start_datetime": "2020-01-01T00:00:00+00:00",
#     "end_datetime": "2020-12-31T23:59:59+00:00",
#     "created_datetime": "2025-06-06T00:00:00+00:00",
#     "proj:epsg": null,
#     "proj:geometry": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             548521.9999999953,
#             2943304.0000000093
#           ],
#           [
#             638521.9999999953,
#             2943304.0000000093
#           ],
#           [
#             638521.9999999953,
#             3033304.0000000093
#           ],
#           [
#             548521.9999999953,
#             3033304.0000000093
#           ],
#           [
#             548521.9999999953,
#             2943304.0000000093
#           ]
#         ]
#       ]
#     },
#     "proj:bbox": [
#       548521.9999999953,
#       2943304.0000000093,
#       638521.9999999953,
#       3033304.0000000093
#     ],
#     "proj:shape": [
#       3000,
#       3000
#     ],
#     "proj:transform": [
#       30.0,
#       0.0,
#       548521.9999999953,
#       0.0,
#       -30.0,
#       3033304.0000000093,
#       0.0,
#       0.0,
#       1.0
#     ],
#     "proj:wkt2": "PROJCS[\"unnamed\",GEOGCS[\"GRS 1980(IUGG, 1980)\",DATUM[\"unknown\",SPHEROID[\"GRS80\",6378137,298.257222101],TOWGS84[0,0,0,0,0,0,0]],PRIMEM[\"Greenwich\",0],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]]],PROJECTION[\"Albers_Conic_Equal_Area\"],PARAMETER[\"latitude_of_center\",40],PARAMETER[\"longitude_of_center\",180],PARAMETER[\"standard_parallel_1\",50],PARAMETER[\"standard_parallel_2\",70],PARAMETER[\"false_easting\",0],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH]]",
#     "datetime": "2020-07-01T23:59:59.500000Z"
#   },
#   "links": [
#     {
#       "rel": "collection",
#       "href": "icesat2-boreal-v3.0-agb",
#       "type": "application/json"
#     }
#   ],
#   "assets": {
#     "cog": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543.tif",
#       "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#       "title": "Gridded predictions of aboveground biomass (Mg/ha)",
#       "description": "Gridded predictions of aboveground biomass (Mg/ha)",
#       "gsd": 30,
#       "processing:level": "L4",
#       "bands": [
#         {
#           "name": "predicted",
#           "sampling": "area",
#           "nodata": -9999.0,
#           "scale": 1.0,
#           "offset": 0.0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "Mg ha-1",
#           "statistics": {
#             "mean": 1.651243781839378,
#             "minimum": 0.40512755513191223,
#             "maximum": 59.68183517456055,
#             "stddev": 2.5398651499605056,
#             "valid_percent": 22.264533333333333
#           },
#           "histogram": {
#             "count": 11,
#             "min": 0.40512755513191223,
#             "max": 59.68183517456055,
#             "buckets": [
#               1942738,
#               36399,
#               13406,
#               4729,
#               3831,
#               2203,
#               312,
#               119,
#               59,
#               12
#             ]
#           }
#         },
#         {
#           "name": "sd",
#           "sampling": "area",
#           "nodata": -9999.0,
#           "scale": 1.0,
#           "offset": 0.0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "Mg ha-1",
#           "statistics": {
#             "mean": 0.6451179454318977,
#             "minimum": 0.10069691389799118,
#             "maximum": 23.654916763305664,
#             "stddev": 1.4006303474929795,
#             "valid_percent": 22.264533333333333
#           },
#           "histogram": {
#             "count": 11,
#             "min": 0.10069691389799118,
#             "max": 23.654916763305664,
#             "buckets": [
#               1903444,
#               58686,
#               20925,
#               8236,
#               4108,
#               4483,
#               3499,
#               348,
#               67,
#               12
#             ]
#           }
#         }
#       ],
#       "roles": [
#         "data"
#       ]
#     },
#     "training_data_csv": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543_train_data.csv",
#       "type": "text/csv",
#       "title": "Tabular training data",
#       "description": "Tabular training data with latitude, longitude, and biomass observations",
#       "roles": [
#         "data"
#       ]
#     }
#   },
#   "collection": "icesat2-boreal-v3.0-agb"
# }

# %% [markdown]
# If that looks good, generate the messages to dispatch to the `StactoolsItemGenerator`

# %%
agb_stactools_messages = generate_stactools_messages(agb_asset_keys, agb_collection.id)

print(json.dumps(agb_stactools_messages[0], indent=2))
# Out:
# {
#   "package_name": "git+https://github.com/MAAP-Project/icesat2-boreal-stac@0.3.1",
#   "group_name": "icesat2boreal",
#   "create_item_args": [
#     "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543.tif",
#     "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/agb/0003543/boreal_agb_2020_202506061749236725_0003543_train_data.csv"
#   ],
#   "collection_id": "icesat2-boreal-v3.0-agb"
# }

# %% [markdown]
# Publish the messages to the `StactoolsItemGenerator` SNS topic!

# %%
publish_stactools_messages(agb_stactools_messages)
# Out:
# --- Processing batch 1 (messages 0 to 9) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 2 (messages 10 to 19) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 3 (messages 20 to 29) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 4 (messages 30 to 39) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 5 (messages 40 to 49) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 6 (messages 50 to 59) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 7 (messages 60 to 69) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 8 (messages 70 to 79) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 9 (messages 80 to 89) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 10 (messages 90 to 99) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 11 (messages 100 to 109) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 12 (messages 110 to 119) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 13 (messages 120 to 129) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 14 (messages 130 to 139) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 15 (messages 140 to 149) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 16 (messages 150 to 159) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 17 (messages 160 to 169) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 18 (messages 170 to 179) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 19 (messages 180 to 189) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 20 (messages 190 to 199) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 21 (messages 200 to 209) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 22 (messages 210 to 219) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 23 (messages 220 to 229) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 24 (messages 230 to 239) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 25 (messages 240 to 249) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 26 (messages 250 to 259) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 27 (messages 260 to 269) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 28 (messages 270 to 279) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 29 (messages 280 to 289) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 30 (messages 290 to 299) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 31 (messages 300 to 309) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 32 (messages 310 to 319) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 33 (messages 320 to 329) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 34 (messages 330 to 339) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 35 (messages 340 to 349) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 36 (messages 350 to 359) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 37 (messages 360 to 369) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 38 (messages 370 to 379) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 39 (messages 380 to 389) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 40 (messages 390 to 399) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 41 (messages 400 to 409) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch
---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 439 (messages 4380 to 4389) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 440 (messages 4390 to 4399) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 441 (messages 4400 to 4409) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 442 (messages 4410 to 4419) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 443 (messages 4420 to 4429) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 444 (messages 4430 to 4439) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 445 (messages 4440 to 4449) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 446 (messages 4450 to 4459) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 447 (messages 4460 to 4469) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 448 (messages 4470 to 4479) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 449 (messages 4480 to 4489) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 450 (messages 4490 to 4499) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 451 (messages 4500 to 4509) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 452 (messages 4510 to 4519) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 453 (messages 4520 to 4529) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 454 (messages 4530 to 4539) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 455 (messages 4540 to 4549) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 456 (messages 4550 to 4559) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 457 (messages 4560 to 4569) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 458 (messages 4570 to 4579) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 459 (messages 4580 to 4589) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 460 (messages 4590 to 4599) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 461 (messages 4600 to 4609) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 462 (messages 4610 to 4619) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 463 (messages 4620 to 4629) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 464 (messages 4630 to 4639) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 465 (messages 4640 to 4649) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 466 (messages 4650 to 4659) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 467 (messages 4660 to 4669) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 468 (messages 4670 to 4679) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 469 (messages 4680 to 4689) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 470 (messages 4690 to 4699) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 471 (messages 4700 to 4709) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 472 (messages 4710 to 4719) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 473 (messages 4720 to 4729) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 474 (messages 4730 to 4739) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 475 (messages 4740 to 4749) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 476 (messages 4750 to 4759) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 477 (messages 4760 to 4769) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 478 (messages 4770 to 4779) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 479 (messages 4780 to 4789) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 480 (messages 4790 to 4799) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 481 (messages 4800 to 4809) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 482 (messages 4810 to 4819) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 483 (messages 4820 to 4829) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 484 (messages 4830 to 4839) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 485 (messages 4840 to 4849) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 486 (messages 4850 to 4859) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 487 (messages 4860 to 4869) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 488 (messages 4870 to 4879) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 489 (messages 4880 to 4889) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 490 (messages 4890 to 4899) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 491 (messages 4900 to 4909) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 492 (messages 4910 to 4919) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 493 (messages 4920 to 4929) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 494 (messages 4930 to 4939) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 495 (messages 4940 to 4949) ---
#   Successfully published 10 messages in this batch.
#
# --- All batches processed ---

# %% [markdown]
# ## Height
#
# Do the same operations but for the `height` collection.

# %%
ht_collection = create_collection(Variable.HT)

# validate
_ = ht_collection.validate()  # pystac
_ = Collection(**ht_collection.to_dict())  # stac-pydantic

print(json.dumps(ht_collection.to_dict(), indent=2))
# Out:
# {
#   "type": "Collection",
#   "id": "icesat2-boreal-v3.0-ht",
#   "stac_version": "1.1.0",
#   "description": "This dataset provides predictions of woody aboveground biomass density (AGBD) and vegetation height for high northern latitude forests at 30 m spatial resolution for the year 2020, accounting for >30% of global forest area.\n\nMaps of woody AGBD and height are essential for understanding patterns of forest structure, including the mass of forest vegetation, its carbon content, and its vertical and horizontal arrangement across managed and unmanaged landscapes. These maps are optimized to visualize these patterns, monitor forest conditions, and manage forest carbon stocks and their changes. The information contained in these maps provides insights into the current conditions and shifts in a global biome that is shaped by natural processes that play out across decades to millennia, as well as human decisions, and whose status and functioning affects wildlife, the climate, economies, and the wellbeing of public and private sector stakeholders both within and outside of the north.\n\nThese maps are built with state-of-the-art earth observation datasets collected from space, including lidar observations from NASA\u2019s ICESat-2 and imagery from NASA\u2019s Harmonized Landsat/Sentinel-2 project. They are designed for circumpolar boreal-wide mapping from local to global scales and provide the northern component of global forest structure estimates, to which complementary estimates from NASA's Global Ecosystem Dynamics Investigation (GEDI) mission contribute temperate and tropical portions. The AGBD and height predictions cover the extent of high latitude boreal forests and shrublands, and while they extend southward outside the boreal domain nominally to ~50\u00b0N they are intended to contribute to global estimates northward from 51.6\u00b0N.\n\nThe compilation of these maps is a final value-added step made possible by decades of investment coupled with world-class expertise from the US Government into engineering, space, and earth science. With this long-term investment, NASA and its federal (USGS, NOAA), international, and private sector partners have conceived of, tested, built, launched, collected and processed data from, and maintained a constellation of, earth observation satellites that provide the fundamental measurements used to build these maps.\n\nThese maps are compiled on a platform built for geoscience algorithm development and data processing that uses Amazon Web Services. This platform (the Multi-mission Algorithm and Analysis Platform; www.maap-project.org) is the result of an international partnership between NASA and the European Space Agency to promote and support science that is accessible, reproducible, and well-documented. This work is the result of a collaboration of a team of scientists and engineers from the University of Maryland-College Park, NASA Goddard Space Flight Center, the University of Texas-Austin, NASA Jet Propulsion Lab, and Development Seed. The primary funding source for this work came through NASA Terrestrial Ecology Program grants associated with NASA\u2019s decade-long Arctic/Boreal Vulnerability Experiment (http://above.nasa.gov)",
#   "links": [
#     {
#       "rel": "about",
#       "href": "https://github.com/lauraduncanson/icesat2_boreal",
#       "type": "text/html",
#       "title": "icesat2_boreal GitHub repository"
#     },
#     {
#       "rel": "predecessor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal",
#       "title": "Previous version (v1.0)"
#     },
#     {
#       "rel": "predecessor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-ht",
#       "title": "Previous version (v2.1)"
#     }
#   ],
#   "stac_extensions": [
#     "https://stac-extensions.github.io/version/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/processing/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/render/v2.0.0/schema.json",
#     "https://stac-extensions.github.io/scientific/v1.0.0/schema.json"
#   ],
#   "item_assets": {
#     "cog": {
#       "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#       "roles": [
#         "data"
#       ],
#       "gsd": 30,
#       "processing:level": "L4",
#       "bands": [
#         {
#           "name": "predicted",
#           "sampling": "area",
#           "nodata": "nan",
#           "scale": 1,
#           "offset": 0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "m"
#         },
#         {
#           "name": "sd",
#           "sampling": "area",
#           "nodata": "nan",
#           "scale": 1,
#           "offset": 0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "m"
#         }
#       ],
#       "title": "Gridded predictions of vegetation height (m)",
#       "description": "Gridded predictions of vegetation height (m)"
#     },
#     "training_data_csv": {
#       "type": "text/csv",
#       "roles": [
#         "data"
#       ],
#       "title": "Tabular training data",
#       "description": "Tabular training data with latitude, longitude, and height observations"
#     }
#   },
#   "version": "v3.0",
#   "deprecated": false,
#   "renders": {
#     "ht_inferno": {
#       "assets": [
#         "cog"
#       ],
#       "title": "Vegetation height (m)",
#       "expression": "cog_b1",
#       "rescale": [
#         [
#           0,
#           30
#         ]
#       ],
#       "colormap_name": "inferno",
#       "minmax_zoom": [
#         6,
#         18
#       ]
#     }
#   },
#   "sci:citation": "Duncanson, L., P.M. Montesano, A. Neuenschwander, A. Zarringhalam, N. Thomas, A. Mandel, D. Minor, E. Guenther, S. Hancock, T. Feng, A. Barciauskas, G.W. Chang, S. Shah, and B.P. Satorius. Circumpolar boreal aboveground biomass mapping with ICESat-2. (in prep.)",
#   "title": "Circumpolar boreal forest structure from ICESat-2 & HLS (2020 v3.0): 30m vegetation height",
#   "extent": {
#     "spatial": {
#       "bbox": [
#         [
#           -180,
#           51.6,
#           180,
#           78
#         ]
#       ]
#     },
#     "temporal": {
#       "interval": [
#         [
#           "2020-01-01T00:00:00Z",
#           "2020-12-31T23:59:59Z"
#         ]
#       ]
#     }
#   },
#   "license": "CC-BY",
#   "providers": [
#     {
#       "name": "MAAP",
#       "description": "The MAAP platform is designed to combine data, algorithms, and computational abilities for the processing and sharing of data related to NASA\u2019s GEDI, ESA\u2019s BIOMASS, and NASA/ISRO\u2019s NISAR missions",
#       "roles": [
#         "processor",
#         "producer",
#         "host"
#       ],
#       "url": "https://maap-project.org",
#       "processing:level": "L4"
#     }
#   ],
#   "summaries": {
#     "platform": [
#       "LANDSAT-8",
#       "LANDSAT-9",
#       "SENTINEL-2A",
#       "SENTINEL-2B",
#       "ICESat-2"
#     ],
#     "instruments": [
#       "Advanced Topographic Laser Altimeter System",
#       "Operational Land Imager",
#       "Operational Land Imager 2",
#       "Sentinel-2 Multispectral Imager"
#     ],
#     "mission": [
#       "ABoVE"
#     ],
#     "processing:level": [
#       "L4"
#     ],
#     "gsd": {
#       "minimum": 30,
#       "maximum": 30
#     }
#   },
#   "assets": {
#     "tiles": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/boreal_tiles_v004.gpkg",
#       "type": "application/geopackage+sqlite3",
#       "title": "Processing tiles",
#       "description": "90 km tile geometries for processing vegetation height predictions",
#       "roles": [
#         "metadata"
#       ]
#     }
#   }
# }

# %%
# post collection to StacLoader
response = sns_client.publish(
    TopicArn=STAC_LOADER_SNS_TOPIC_ARN, Message=json.dumps(ht_collection.to_dict())
)
print(response)
# Out:
# {'MessageId': '0704c8e8-0b39-5746-ac40-a80468754ad8', 'ResponseMetadata': {'RequestId': '606921d8-6de0-5d95-a02e-41340eacc00b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '606921d8-6de0-5d95-a02e-41340eacc00b', 'date': 'Sat, 12 Jul 2025 13:20:12 GMT', 'content-type': 'text/xml', 'content-length': '294', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}

# %%
ht_inventory = read_inventory(ht_inventory_key)

print(ht_inventory.shape)
ht_inventory.head()
# Out:
# (4950, 5)
#    index                                            s3_path  \
# 0      0  s3://maap-ops-workspace/aliz237/dps_output/run...
# 1      1  s3://maap-ops-workspace/aliz237/dps_output/run...
# 2      2  s3://maap-ops-workspace/aliz237/dps_output/run...
# 3      3  s3://maap-ops-workspace/aliz237/dps_output/run...
# 4      4  s3://maap-ops-workspace/aliz237/dps_output/run...
#
#                                           local_path  \
# 0  /projects/my-private-bucket/dps_output/run_bor...
# 1  /projects/my-private-bucket/dps_output/run_bor...
# 2  /projects/my-private-bucket/dps_output/run_bor...
# 3  /projects/my-private-bucket/dps_output/run_bor...
# 4  /projects/my-private-bucket/dps_output/run_bor...
#
#                                             file  tile_num
# 0  boreal_ht_2020_202506061749238093_0003543.tif      3543
# 1  boreal_ht_2020_202506061749238118_0035805.tif     35805
# 2  boreal_ht_2020_202506061749238121_0035804.tif     35804
# 3  boreal_ht_2020_202506061749238167_0001575.tif      1575
# 4  boreal_ht_2020_202506061749238134_0035803.tif     35803

# %%
ht_cog_key_mappings, ht_csv_key_mappings = generate_key_mappings(ht_inventory, "ht")
print(ht_cog_key_mappings[0])
print(ht_csv_key_mappings[0])
# Out:
# ('aliz237/dps_output/run_boreal_biomass_map/v3.0.0/Ht_H30_2020/full_run/2025/06/06/12/58/00/580429/boreal_ht_2020_202506061749238093_0003543.tif', 'file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543.tif')
# ('aliz237/dps_output/run_boreal_biomass_map/v3.0.0/Ht_H30_2020/full_run/2025/06/06/12/58/00/580429/boreal_ht_2020_202506061749238093_0003543_train_data.csv', 'file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543_train_data.csv')

# %%
await copy_s3_keys(
    source_bucket_name=MAAP_OPS_BUCKET,
    destination_bucket_name=ASSET_DEST_BUCKET,
    key_mapping_tuples=ht_cog_key_mappings + ht_csv_key_mappings,
    aws_region=AWS_REGION,
)
# Out:
# Copying S3 Objects: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9900/9900 [25:26<00:00,  6.49file/s]
# Completed S3 copy operation. All 9900 files copied successfully.

# %%
ht_asset_keys = generate_asset_keys(
    ht_cog_key_mappings, ht_csv_key_mappings, bucket=ASSET_DEST_BUCKET
)
ht_asset_keys[0]
# Out:
# ('s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543.tif',
#  's3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543_train_data.csv')

# %%
test_item = create_item(*ht_asset_keys[0])
print(json.dumps(test_item.to_dict(), indent=2))
# Out:
# {
#   "type": "Feature",
#   "stac_version": "1.1.0",
#   "stac_extensions": [
#     "https://stac-extensions.github.io/projection/v1.1.0/schema.json"
#   ],
#   "id": "boreal_ht_2020_202506061749238093_0003543",
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -167.7268555007834,
#           65.958744412074
#         ],
#         [
#           -165.7687890462486,
#           65.80241344492612
#         ],
#         [
#           -165.33767128760388,
#           66.58197078937214
#         ],
#         [
#           -167.35203068347897,
#           66.74321074546818
#         ],
#         [
#           -167.7268555007834,
#           65.958744412074
#         ]
#       ]
#     ]
#   },
#   "bbox": [
#     -167.7268555007834,
#     65.80241344492612,
#     -165.33767128760388,
#     66.74321074546818
#   ],
#   "properties": {
#     "start_datetime": "2020-01-01T00:00:00+00:00",
#     "end_datetime": "2020-12-31T23:59:59+00:00",
#     "created_datetime": "2025-06-06T00:00:00+00:00",
#     "proj:epsg": null,
#     "proj:geometry": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             548521.9999999953,
#             2943304.0000000093
#           ],
#           [
#             638521.9999999953,
#             2943304.0000000093
#           ],
#           [
#             638521.9999999953,
#             3033304.0000000093
#           ],
#           [
#             548521.9999999953,
#             3033304.0000000093
#           ],
#           [
#             548521.9999999953,
#             2943304.0000000093
#           ]
#         ]
#       ]
#     },
#     "proj:bbox": [
#       548521.9999999953,
#       2943304.0000000093,
#       638521.9999999953,
#       3033304.0000000093
#     ],
#     "proj:shape": [
#       3000,
#       3000
#     ],
#     "proj:transform": [
#       30.0,
#       0.0,
#       548521.9999999953,
#       0.0,
#       -30.0,
#       3033304.0000000093,
#       0.0,
#       0.0,
#       1.0
#     ],
#     "proj:wkt2": "PROJCS[\"unnamed\",GEOGCS[\"GRS 1980(IUGG, 1980)\",DATUM[\"unknown\",SPHEROID[\"GRS80\",6378137,298.257222101],TOWGS84[0,0,0,0,0,0,0]],PRIMEM[\"Greenwich\",0],UNIT[\"degree\",0.0174532925199433,AUTHORITY[\"EPSG\",\"9122\"]]],PROJECTION[\"Albers_Conic_Equal_Area\"],PARAMETER[\"latitude_of_center\",40],PARAMETER[\"longitude_of_center\",180],PARAMETER[\"standard_parallel_1\",50],PARAMETER[\"standard_parallel_2\",70],PARAMETER[\"false_easting\",0],PARAMETER[\"false_northing\",0],UNIT[\"metre\",1,AUTHORITY[\"EPSG\",\"9001\"]],AXIS[\"Easting\",EAST],AXIS[\"Northing\",NORTH]]",
#     "datetime": "2020-07-01T23:59:59.500000Z"
#   },
#   "links": [
#     {
#       "rel": "collection",
#       "href": "icesat2-boreal-v3.0-ht",
#       "type": "application/json"
#     }
#   ],
#   "assets": {
#     "cog": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543.tif",
#       "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#       "title": "Gridded predictions of vegetation height (m)",
#       "description": "Gridded predictions of vegetation height (m)",
#       "gsd": 30,
#       "processing:level": "L4",
#       "bands": [
#         {
#           "name": "predicted",
#           "sampling": "area",
#           "nodata": -9999.0,
#           "scale": 1.0,
#           "offset": 0.0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "m",
#           "statistics": {
#             "mean": 0.8832962040275316,
#             "minimum": 0.030877357348799706,
#             "maximum": 12.111003875732422,
#             "stddev": 0.7871584537531102,
#             "valid_percent": 22.264533333333333
#           },
#           "histogram": {
#             "count": 11,
#             "min": 0.030877357348799706,
#             "max": 12.111003875732422,
#             "buckets": [
#               1689598,
#               229403,
#               46656,
#               20222,
#               13361,
#               3442,
#               758,
#               276,
#               82,
#               10
#             ]
#           }
#         },
#         {
#           "name": "sd",
#           "sampling": "area",
#           "nodata": -9999.0,
#           "scale": 1.0,
#           "offset": 0.0,
#           "data_type": "float32",
#           "spatial_resolution": 30,
#           "unit": "m",
#           "statistics": {
#             "mean": 0.23377824559538637,
#             "minimum": 0.022471105679869652,
#             "maximum": 3.39129376411438,
#             "stddev": 0.29066269830307406,
#             "valid_percent": 22.264533333333333
#           },
#           "histogram": {
#             "count": 11,
#             "min": 0.022471105679869652,
#             "max": 3.39129376411438,
#             "buckets": [
#               1682131,
#               203397,
#               57096,
#               27567,
#               15943,
#               12896,
#               3731,
#               936,
#               93,
#               18
#             ]
#           }
#         }
#       ],
#       "roles": [
#         "data"
#       ]
#     },
#     "training_data_csv": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543_train_data.csv",
#       "type": "text/csv",
#       "title": "Tabular training data",
#       "description": "Tabular training data with latitude, longitude, and height observations",
#       "roles": [
#         "data"
#       ]
#     }
#   },
#   "collection": "icesat2-boreal-v3.0-ht"
# }

# %%
ht_stactools_messages = generate_stactools_messages(ht_asset_keys, ht_collection.id)

print(json.dumps(ht_stactools_messages[0], indent=2))
# Out:
# {
#   "package_name": "git+https://github.com/MAAP-Project/icesat2-boreal-stac@0.3.1",
#   "group_name": "icesat2boreal",
#   "create_item_args": [
#     "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543.tif",
#     "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v3.0/ht/0003543/boreal_ht_2020_202506061749238093_0003543_train_data.csv"
#   ],
#   "collection_id": "icesat2-boreal-v3.0-ht"
# }

# %%
publish_stactools_messages(ht_stactools_messages)
# Out:
# --- Processing batch 1 (messages 0 to 9) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 2 (messages 10 to 19) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 3 (messages 20 to 29) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 4 (messages 30 to 39) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 5 (messages 40 to 49) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 6 (messages 50 to 59) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 7 (messages 60 to 69) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 8 (messages 70 to 79) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 9 (messages 80 to 89) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 10 (messages 90 to 99) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 11 (messages 100 to 109) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 12 (messages 110 to 119) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 13 (messages 120 to 129) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 14 (messages 130 to 139) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 15 (messages 140 to 149) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 16 (messages 150 to 159) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 17 (messages 160 to 169) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 18 (messages 170 to 179) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 19 (messages 180 to 189) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 20 (messages 190 to 199) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 21 (messages 200 to 209) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 22 (messages 210 to 219) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 23 (messages 220 to 229) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 24 (messages 230 to 239) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 25 (messages 240 to 249) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 26 (messages 250 to 259) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 27 (messages 260 to 269) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 28 (messages 270 to 279) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 29 (messages 280 to 289) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 30 (messages 290 to 299) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 31 (messages 300 to 309) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 32 (messages 310 to 319) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 33 (messages 320 to 329) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 34 (messages 330 to 339) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 35 (messages 340 to 349) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 36 (messages 350 to 359) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 37 (messages 360 to 369) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 38 (messages 370 to 379) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 39 (messages 380 to 389) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 40 (messages 390 to 399) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 41 (messages 400 to 409) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 42 (messages 410 to 419) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 43 (messages 420 to 429) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 44 (messages 430 to 439) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 45 (messages 440 to 449) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 46 (messages 450 to 459) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 47 (messages 460 to 469) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 48 (messages 470 to 479) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 49 (messages 480 to 489) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 50 (messages 490 to 499) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 51 (messages 500 to 509) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 52 (messages 510 to 519) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 53 (messages 520 to 529) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 54 (messages 530 to 539) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch
---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 451 (messages 4500 to 4509) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 452 (messages 4510 to 4519) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 453 (messages 4520 to 4529) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 454 (messages 4530 to 4539) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 455 (messages 4540 to 4549) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 456 (messages 4550 to 4559) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 457 (messages 4560 to 4569) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 458 (messages 4570 to 4579) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 459 (messages 4580 to 4589) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 460 (messages 4590 to 4599) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 461 (messages 4600 to 4609) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 462 (messages 4610 to 4619) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 463 (messages 4620 to 4629) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 464 (messages 4630 to 4639) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 465 (messages 4640 to 4649) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 466 (messages 4650 to 4659) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 467 (messages 4660 to 4669) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 468 (messages 4670 to 4679) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 469 (messages 4680 to 4689) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 470 (messages 4690 to 4699) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 471 (messages 4700 to 4709) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 472 (messages 4710 to 4719) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 473 (messages 4720 to 4729) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 474 (messages 4730 to 4739) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 475 (messages 4740 to 4749) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 476 (messages 4750 to 4759) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 477 (messages 4760 to 4769) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 478 (messages 4770 to 4779) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 479 (messages 4780 to 4789) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 480 (messages 4790 to 4799) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 481 (messages 4800 to 4809) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 482 (messages 4810 to 4819) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 483 (messages 4820 to 4829) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 484 (messages 4830 to 4839) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 485 (messages 4840 to 4849) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 486 (messages 4850 to 4859) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 487 (messages 4860 to 4869) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 488 (messages 4870 to 4879) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 489 (messages 4880 to 4889) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 490 (messages 4890 to 4899) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 491 (messages 4900 to 4909) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 492 (messages 4910 to 4919) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 493 (messages 4920 to 4929) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 494 (messages 4930 to 4939) ---
#   Successfully published 10 messages in this batch.
#
# --- Processing batch 495 (messages 4940 to 4949) ---
#   Successfully published 10 messages in this batch.
#
# --- All batches processed ---

# %% [markdown]
# ## Mark v2.1 collections as deprecated
#
# Now that v3.0 is out, we can mark v2.1 as deprecated!

# %%
from pystac import Link
from pystac.extensions.version import VersionRelType


client = pystac_client.Client.open("https://stac.maap-project.org")
agb_2_1 = client.get_collection("icesat2-boreal-v2.1-agb")

agb_2_1.ext.version.deprecated = True

agb_2_1.add_link(
    Link(
        rel=VersionRelType.SUCCESSOR,
        target="https://stac.maap-project.org/collections/icesat2-boreal-v3.0-agb",
        title="Latest version (v3.0)",
    )
)

agb_2_1.title = agb_collection.title.replace("v3.0", "v2.1")


# validate
_ = agb_2_1.validate()  # pystac
_ = Collection(**agb_2_1.to_dict())  # stac-pydantic

print(json.dumps(agb_2_1.to_dict(), indent=2))
# Out:
# {
#   "type": "Collection",
#   "id": "icesat2-boreal-v2.1-agb",
#   "stac_version": "1.1.0",
#   "description": "This dataset provides predictions of woody Aboveground Biomass Density (AGBD) and vegetation height for high northern latitude forests at a 30-m spatial resolution. It is designed both for circumpolar boreal-wide mapping and filling the northern spatial data gap from NASA's Global Ecosystem Dynamics Investigation (GEDI) mission. Mapping woody AGBD and height is essential for understanding, monitoring, and managing forest carbon stocks and fluxes. The AGBD and height predictions cover the extent of high latitude boreal forests and shrublands, and extend southward outside the boreal domain to 51.6\u00b0N. These maps represent conditions in 2020.\n\nICESat-2 ATL08 represented the training data for these mapped products, with ATL08\u2019s maximum height (h_canopy) used to train the height product, and estimates of 30-m AGBD from ATL08 used to train the AGBD product. AGBD and vegetation models were developed using local moving window models, with models produced for a suite of 90 km tiles.\n\nPrediction of AGBD involved two modeling steps: (1) regression with ordinary least squares (OLS) to relate field plot measurements of AGBD to NASA's ICESat-2 30-m ATL08 lidar samples, and (2) machine learning modeling with random forest to extend estimates beyond the field plots by relating ICESat-2 AGBD predictions to wall-to-wall gridded covariate stacks from Harmonized Landsat/Sentinel-2 (HLS) and the Copernicus GLO30 DEM. Per-pixel uncertainties are estimated from bootstrapping both models.\n\nPrediction of vegetation height used the second of the two steps for AGBD, since what would otherwise be the dependent variable (height) is a direct measurement from ICESat-2 ATL08. Uncertainty was therefore estimated from bootstrapping the random forest model, with no propagation of any uncertainties from the ICESat-2 height measurements.\n\nUncertainties were estimated using bootstrapping of training data to produce a suite of models and maps, which were then summarized to produce pixel-level standard error estimates. Models were re-fit for each 90 km tile until the variance of the 90 km AGBD total stabilized (less than 5% change in the variance of tile total AGBD). The pixel-level SD is calculated as the SD of the set of pixel predictions from these iterations.\n\nThis dataset features predictions for landcovers that are associated with the full woody structure gradient according to the European Space Agency\u2019s Worldcover v1.0 2020 dataset. This primarily includes forests, shrubs, and grass extents in which woody vegetation is present. Importantly, predictions were also made for the \u2018moss/lichen\u2019 land cover. The decision to include these pixels considered the broad domain of this study, where areas from the far north down to southern portions featured this classification, but represented very different apparent land uses. In northern portions, this classification occurs frequently across tundra extents (eg, the Brooks Range), whereas in the south it appears at sites of recent forest clearing. Non-vegetated land covers (e.g. built up, water, rock, ice) were masked out of our predictions.\n\nHLS composites and ICESat-2 data were from 2020 to produce a single-year 2020 map. ICESat-2 data were filtered to include only strong beams, growing seasons (June through September), solar elevations less than 5 degrees, snow free land (snow flag set to 1), and \"msw_flag\" equal to 0 (clear skies and no observed atmospheric scattering). ICESat-2's ATL08 product was resampled to a 30-m spatial resolution to better match both the field plots and mapped pixels, which involved reprocessing the nominal 100-m segments to 30-m segments. HLS data (both the L30 and S30 products) were used to create a harmonized (HLSH30) greenest pixel composite of growing season multispectral data, which was then used to compute a suite of vegetation indices: NDVI, NDWI, NBR, NBR2, TCW, TCG. These were then used, in combination with a suite of topographic ...
#   "links": [
#     {
#       "rel": "items",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-agb/items",
#       "type": "application/geo+json"
#     },
#     {
#       "rel": "parent",
#       "href": "https://stac.maap-project.org/",
#       "type": "application/json"
#     },
#     {
#       "rel": "root",
#       "href": "https://stac.maap-project.org",
#       "type": "application/json",
#       "title": "MAAP public STAC API (dev)"
#     },
#     {
#       "rel": "self",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-agb",
#       "type": "application/json"
#     },
#     {
#       "rel": "items",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-agb/items",
#       "type": "application/geo+json"
#     },
#     {
#       "rel": "about",
#       "href": "https://github.com/lauraduncanson/icesat2_boreal",
#       "type": "text/html",
#       "title": "icesat2_boreal GitHub repository"
#     },
#     {
#       "rel": "predecessor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal",
#       "title": "Previous version"
#     },
#     {
#       "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-agb/queryables",
#       "type": "application/schema+json",
#       "title": "Queryables"
#     },
#     {
#       "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-agb/queryables",
#       "type": "application/schema+json",
#       "title": "Queryables"
#     },
#     {
#       "rel": "successor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v3.0-agb",
#       "title": "Latest version (v3.0)"
#     }
#   ],
#   "stac_extensions": [
#     "https://stac-extensions.github.io/version/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/processing/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/render/v2.0.0/schema.json",
#     "https://stac-extensions.github.io/scientific/v1.0.0/schema.json"
#   ],
#   "renders": {
#     "agb_viridis": {
#       "title": "Aboveground biomass (Mg/ha)",
#       "assets": [
#         "cog"
#       ],
#       "rescale": [
#         [
#           0,
#           125
#         ]
#       ],
#       "expression": "cog_b1",
#       "minmax_zoom": [
#         6,
#         18
#       ],
#       "colormap_name": "viridis"
#     },
#     "agb_gist_earth_r": {
#       "title": "Aboveground biomass (Mg/ha)",
#       "assets": [
#         "cog"
#       ],
#       "rescale": [
#         [
#           0,
#           400
#         ]
#       ],
#       "expression": "cog_b1",
#       "minmax_zoom": [
#         6,
#         18
#       ],
#       "color_formula": "gamma r 1.05",
#       "colormap_name": "gist_earth_r"
#     }
#   },
#   "version": "v2.1",
#   "deprecated": true,
#   "item_assets": {
#     "cog": {
#       "gsd": 30,
#       "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#       "bands": [
#         {
#           "scale": 1,
#           "nodata": "nan",
#           "offset": 0,
#           "sampling": "area",
#           "data_type": "float32"
#         },
#         {
#           "scale": 1,
#           "nodata": "nan",
#           "offset": 0,
#           "sampling": "area",
#           "data_type": "float32"
#         }
#       ],
#       "roles": [
#         "data"
#       ],
#       "title": "Gridded predictions of aboveground biomass (Mg/ha)",
#       "description": "Gridded predictions of aboveground biomass (Mg/ha)",
#       "processing:level": "L4"
#     },
#     "training_data_csv": {
#       "type": "text/csv",
#       "roles": [
#         "data"
#       ],
#       "title": "Tabular training data",
#       "description": "Tabular training data with latitude, longitude, and biomass observations"
#     }
#   },
#   "sci:citation": "Duncanson, L., P.M. Montesano, A. Neuenschwander, A. Zarringhalam, N. Thomas, A. Mandel, D. Minor, E. Guenther, S. Hancock, T. Feng, A. Barciauskas, G.W. Chang, S. Shah, and B.P. Satorius. Circumpolar boreal aboveground biomass mapping with ICESat-2. (in prep.)",
#   "title": "Circumpolar boreal forest structure from ICESat-2 & HLS (2020 v2.1): 30m aboveground woody biomass density",
#   "extent": {
#     "spatial": {
#       "bbox": [
#         [
#           -180,
#           51.6,
#           180,
#           78
#         ]
#       ]
#     },
#     "temporal": {
#       "interval": [
#         [
#           "2020-01-01T00:00:00Z",
#           "2020-12-31T23:59:59Z"
#         ]
#       ]
#     }
#   },
#   "license": "CC-BY",
#   "providers": [
#     {
#       "name": "MAAP",
#       "description": "The MAAP platform is designed to combine data, algorithms, and computational abilities for the processing and sharing of data related to NASA\u2019s GEDI, ESA\u2019s BIOMASS, and NASA/ISRO\u2019s NISAR missions",
#       "roles": [
#         "processor",
#         "producer",
#         "host"
#       ],
#       "url": "https://maap-project.org"
#     }
#   ],
#   "summaries": {
#     "mission": [
#       "ABoVE"
#     ],
#     "platform": [
#       "LANDSAT-8",
#       "LANDSAT-9",
#       "SENTINEL-2A",
#       "SENTINEL-2B",
#       "ICESat-2"
#     ],
#     "instruments": [
#       "Advanced Topographic Laser Altimeter System",
#       "Operational Land Imager",
#       "Operational Land Imager 2",
#       "Sentinel-2 Multispectral Imager"
#     ],
#     "processing:level": [
#       "L4"
#     ],
#     "gsd": {
#       "minimum": 30,
#       "maximum": 30
#     }
#   },
#   "assets": {
#     "tiles": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v2.1/agb/boreal_tiles_v004_AGB_H30_2020_ORNLDAAC.gpkg",
#       "type": "application/geopackage+sqlite3",
#       "title": "Processing tiles",
#       "description": "90 km tile geometries for processing AGB predictions",
#       "roles": [
#         "metadata"
#       ]
#     }
#   }
# }

# %%
# post collection to StacLoader
response = sns_client.publish(
    TopicArn=STAC_LOADER_SNS_TOPIC_ARN, Message=json.dumps(agb_2_1.to_dict())
)
print(response)
# Out:
# {'MessageId': '74a6c6c1-0f6a-51cb-93ed-a62d7e6e1401', 'ResponseMetadata': {'RequestId': '1ae68f22-fd6e-5fed-af38-efce8c6dca27', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1ae68f22-fd6e-5fed-af38-efce8c6dca27', 'date': 'Sat, 12 Jul 2025 14:18:44 GMT', 'content-type': 'text/xml', 'content-length': '294', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}

# %%
client = pystac_client.Client.open("https://stac.maap-project.org")
ht_2_1 = client.get_collection("icesat2-boreal-v2.1-ht")

ht_2_1.ext.version.deprecated = True

ht_2_1.add_link(
    Link(
        rel=VersionRelType.SUCCESSOR,
        target="https://stac.maap-project.org/collections/icesat2-boreal-v3.0-ht",
        title="Latest version (v3.0)",
    )
)

ht_2_1.title = ht_collection.title.replace("v3.0", "v2.1")

# validate
_ = ht_2_1.validate()  # pystac
_ = Collection(**ht_2_1.to_dict())  # stac-pydantic

print(json.dumps(ht_2_1.to_dict(), indent=2))
# Out:
# {
#   "type": "Collection",
#   "id": "icesat2-boreal-v2.1-ht",
#   "stac_version": "1.1.0",
#   "description": "This dataset provides predictions of woody Aboveground Biomass Density (AGBD) and vegetation height for high northern latitude forests at a 30-m spatial resolution. It is designed both for circumpolar boreal-wide mapping and filling the northern spatial data gap from NASA's Global Ecosystem Dynamics Investigation (GEDI) mission. Mapping woody AGBD and height is essential for understanding, monitoring, and managing forest carbon stocks and fluxes. The AGBD and height predictions cover the extent of high latitude boreal forests and shrublands, and extend southward outside the boreal domain to 51.6\u00b0N. These maps represent conditions in 2020.\n\nICESat-2 ATL08 represented the training data for these mapped products, with ATL08\u2019s maximum height (h_canopy) used to train the height product, and estimates of 30-m AGBD from ATL08 used to train the AGBD product. AGBD and vegetation models were developed using local moving window models, with models produced for a suite of 90 km tiles.\n\nPrediction of AGBD involved two modeling steps: (1) regression with ordinary least squares (OLS) to relate field plot measurements of AGBD to NASA's ICESat-2 30-m ATL08 lidar samples, and (2) machine learning modeling with random forest to extend estimates beyond the field plots by relating ICESat-2 AGBD predictions to wall-to-wall gridded covariate stacks from Harmonized Landsat/Sentinel-2 (HLS) and the Copernicus GLO30 DEM. Per-pixel uncertainties are estimated from bootstrapping both models.\n\nPrediction of vegetation height used the second of the two steps for AGBD, since what would otherwise be the dependent variable (height) is a direct measurement from ICESat-2 ATL08. Uncertainty was therefore estimated from bootstrapping the random forest model, with no propagation of any uncertainties from the ICESat-2 height measurements.\n\nUncertainties were estimated using bootstrapping of training data to produce a suite of models and maps, which were then summarized to produce pixel-level standard error estimates. Models were re-fit for each 90 km tile until the variance of the 90 km AGBD total stabilized (less than 5% change in the variance of tile total AGBD). The pixel-level SD is calculated as the SD of the set of pixel predictions from these iterations.\n\nThis dataset features predictions for landcovers that are associated with the full woody structure gradient according to the European Space Agency\u2019s Worldcover v1.0 2020 dataset. This primarily includes forests, shrubs, and grass extents in which woody vegetation is present. Importantly, predictions were also made for the \u2018moss/lichen\u2019 land cover. The decision to include these pixels considered the broad domain of this study, where areas from the far north down to southern portions featured this classification, but represented very different apparent land uses. In northern portions, this classification occurs frequently across tundra extents (eg, the Brooks Range), whereas in the south it appears at sites of recent forest clearing. Non-vegetated land covers (e.g. built up, water, rock, ice) were masked out of our predictions.\n\nHLS composites and ICESat-2 data were from 2020 to produce a single-year 2020 map. ICESat-2 data were filtered to include only strong beams, growing seasons (June through September), solar elevations less than 5 degrees, snow free land (snow flag set to 1), and \"msw_flag\" equal to 0 (clear skies and no observed atmospheric scattering). ICESat-2's ATL08 product was resampled to a 30-m spatial resolution to better match both the field plots and mapped pixels, which involved reprocessing the nominal 100-m segments to 30-m segments. HLS data (both the L30 and S30 products) were used to create a harmonized (HLSH30) greenest pixel composite of growing season multispectral data, which was then used to compute a suite of vegetation indices: NDVI, NDWI, NBR, NBR2, TCW, TCG. These were then used, in combination with a suite of topographic ...
#   "links": [
#     {
#       "rel": "items",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-ht/items",
#       "type": "application/geo+json"
#     },
#     {
#       "rel": "parent",
#       "href": "https://stac.maap-project.org/",
#       "type": "application/json"
#     },
#     {
#       "rel": "root",
#       "href": "https://stac.maap-project.org",
#       "type": "application/json",
#       "title": "MAAP public STAC API (dev)"
#     },
#     {
#       "rel": "self",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-ht",
#       "type": "application/json"
#     },
#     {
#       "rel": "items",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-ht/items",
#       "type": "application/geo+json"
#     },
#     {
#       "rel": "about",
#       "href": "https://github.com/lauraduncanson/icesat2_boreal",
#       "type": "text/html",
#       "title": "icesat2_boreal GitHub repository"
#     },
#     {
#       "rel": "predecessor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal",
#       "title": "Previous version"
#     },
#     {
#       "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-ht/queryables",
#       "type": "application/schema+json",
#       "title": "Queryables"
#     },
#     {
#       "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-ht/queryables",
#       "type": "application/schema+json",
#       "title": "Queryables"
#     },
#     {
#       "rel": "successor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v3.0-ht",
#       "title": "Latest version (v3.0)"
#     }
#   ],
#   "stac_extensions": [
#     "https://stac-extensions.github.io/version/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/processing/v1.2.0/schema.json",
#     "https://stac-extensions.github.io/render/v2.0.0/schema.json",
#     "https://stac-extensions.github.io/scientific/v1.0.0/schema.json"
#   ],
#   "renders": {
#     "ht_inferno": {
#       "title": "Vegetation height (m)",
#       "assets": [
#         "cog"
#       ],
#       "rescale": [
#         [
#           0,
#           30
#         ]
#       ],
#       "expression": "cog_b1",
#       "minmax_zoom": [
#         6,
#         18
#       ],
#       "colormap_name": "inferno"
#     }
#   },
#   "version": "v2.1",
#   "deprecated": true,
#   "item_assets": {
#     "cog": {
#       "gsd": 30,
#       "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#       "bands": [
#         {
#           "scale": 1,
#           "nodata": "nan",
#           "offset": 0,
#           "sampling": "area",
#           "data_type": "float32"
#         },
#         {
#           "scale": 1,
#           "nodata": "nan",
#           "offset": 0,
#           "sampling": "area",
#           "data_type": "float32"
#         }
#       ],
#       "roles": [
#         "data"
#       ],
#       "title": "Gridded predictions of vegetation height (m)",
#       "description": "Gridded predictions of vegetation height (m)",
#       "processing:level": "L4"
#     },
#     "training_data_csv": {
#       "type": "text/csv",
#       "roles": [
#         "data"
#       ],
#       "title": "Tabular training data",
#       "description": "Tabular training data with latitude, longitude, and height observations"
#     }
#   },
#   "sci:citation": "Duncanson, L., P.M. Montesano, A. Neuenschwander, A. Zarringhalam, N. Thomas, A. Mandel, D. Minor, E. Guenther, S. Hancock, T. Feng, A. Barciauskas, G.W. Chang, S. Shah, and B.P. Satorius. Circumpolar boreal aboveground biomass mapping with ICESat-2. (in prep.)",
#   "title": "Circumpolar boreal forest structure from ICESat-2 & HLS (2020 v2.1): 30m vegetation height",
#   "extent": {
#     "spatial": {
#       "bbox": [
#         [
#           -180,
#           51.6,
#           180,
#           78
#         ]
#       ]
#     },
#     "temporal": {
#       "interval": [
#         [
#           "2020-01-01T00:00:00Z",
#           "2020-12-31T23:59:59Z"
#         ]
#       ]
#     }
#   },
#   "license": "CC-BY",
#   "providers": [
#     {
#       "name": "MAAP",
#       "description": "The MAAP platform is designed to combine data, algorithms, and computational abilities for the processing and sharing of data related to NASA\u2019s GEDI, ESA\u2019s BIOMASS, and NASA/ISRO\u2019s NISAR missions",
#       "roles": [
#         "processor",
#         "producer",
#         "host"
#       ],
#       "url": "https://maap-project.org"
#     }
#   ],
#   "summaries": {
#     "mission": [
#       "ABoVE"
#     ],
#     "platform": [
#       "LANDSAT-8",
#       "LANDSAT-9",
#       "SENTINEL-2A",
#       "SENTINEL-2B",
#       "ICESat-2"
#     ],
#     "instruments": [
#       "Advanced Topographic Laser Altimeter System",
#       "Operational Land Imager",
#       "Operational Land Imager 2",
#       "Sentinel-2 Multispectral Imager"
#     ],
#     "processing:level": [
#       "L4"
#     ],
#     "gsd": {
#       "minimum": 30,
#       "maximum": 30
#     }
#   },
#   "assets": {
#     "tiles": {
#       "href": "s3://nasa-maap-data-store/file-staging/nasa-map/icesat2-boreal-v2.1/ht/boreal_tiles_v004_HT_H30_2020_ORNLDAAC.gpkg",
#       "type": "application/geopackage+sqlite3",
#       "title": "Processing tiles",
#       "description": "90 km tile geometries for processing vegetation height predictions",
#       "roles": [
#         "metadata"
#       ]
#     }
#   }
# }

# %%
# post collection to StacLoader
response = sns_client.publish(
    TopicArn=STAC_LOADER_SNS_TOPIC_ARN, Message=json.dumps(ht_2_1.to_dict())
)
print(response)
# Out:
# {'MessageId': 'f4c2403b-c14a-5384-aba1-20d7b0621707', 'ResponseMetadata': {'RequestId': '52b4a595-add3-5de4-8a97-c579dcfbc967', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '52b4a595-add3-5de4-8a97-c579dcfbc967', 'date': 'Sat, 12 Jul 2025 14:19:20 GMT', 'content-type': 'text/xml', 'content-length': '294', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}

# %%
agb_1_0 = client.get_collection("icesat2-boreal")

agb_1_0.ext.version.deprecated = True

for link in agb_1_0.links:
    if link.rel == VersionRelType.LATEST:
        link.rel = VersionRelType.SUCCESSOR
        link.title = "Successor version (v2.1)"

agb_1_0.add_link(
    Link(
        rel=VersionRelType.LATEST,
        target="https://stac.maap-project.org/collections/icesat2-boreal-v3.0-agb",
        title="Latest version (v3.0)",
    )
)


agb_1_0.title = agb_collection.title.replace("v3.0", "v1.0")


# validate
_ = agb_1_0.validate()  # pystac
_ = Collection(**agb_1_0.to_dict())  # stac-pydantic

print(json.dumps(agb_1_0.to_dict(), indent=2))
# Out:
# /home/henry/.cache/uv/environments-v2/juv-tmp-o9mk7bs3-f414ae7b1cca69fd/lib/python3.13/site-packages/pystac/collection.py:703: DeprecatedWarning: The collection 'icesat2-boreal' is deprecated.
#   warnings.warn(
# {
#   "type": "Collection",
#   "id": "icesat2-boreal",
#   "stac_version": "1.1.0",
#   "description": "Aboveground biomass density c.2020 gridded to 30m derived from ICESat-2, Harmonized Landsat-Sentinel2 and Copernicus DEM. Band 1 is the data band. Band 2 is the standard deviation.",
#   "links": [
#     {
#       "rel": "items",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal/items",
#       "type": "application/geo+json"
#     },
#     {
#       "rel": "parent",
#       "href": "https://stac.maap-project.org/",
#       "type": "application/json"
#     },
#     {
#       "rel": "root",
#       "href": "https://stac.maap-project.org",
#       "type": "application/json",
#       "title": "MAAP public STAC API (dev)"
#     },
#     {
#       "rel": "self",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal",
#       "type": "application/json"
#     },
#     {
#       "rel": "items",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal/items",
#       "type": "application/geo+json"
#     },
#     {
#       "rel": "successor-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v2.1-agb",
#       "title": "Successor version (v2.1)"
#     },
#     {
#       "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal/queryables",
#       "type": "application/schema+json",
#       "title": "Queryables"
#     },
#     {
#       "rel": "http://www.opengis.net/def/rel/ogc/1.0/queryables",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal/queryables",
#       "type": "application/schema+json",
#       "title": "Queryables"
#     },
#     {
#       "rel": "latest-version",
#       "href": "https://stac.maap-project.org/collections/icesat2-boreal-v3.0-agb",
#       "title": "Latest version (v3.0)"
#     }
#   ],
#   "stac_extensions": [
#     "https://stac-extensions.github.io/render/v1.0.0/schema.json",
#     "https://stac-extensions.github.io/version/v1.2.0/schema.json"
#   ],
#   "renders": {
#     "agb": {
#       "bidx": [
#         1
#       ],
#       "title": "ICESat-2 Boreal Biomass",
#       "assets": [
#         "tif"
#       ],
#       "nodata": "nan",
#       "rescale": [
#         [
#           0,
#           400
#         ]
#       ],
#       "colormap_name": "gist_earth_r"
#     }
#   },
#   "version": "v1.0",
#   "deprecated": true,
#   "item_assets": {
#     "csv": {
#       "type": "text/csv",
#       "roles": [
#         "data"
#       ],
#       "title": "CSV",
#       "description": "CSV of training data"
#     },
#     "tif": {
#       "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#       "roles": [
#         "data",
#         "layer"
#       ],
#       "title": "Cloud Optimized GeoTIFF of boreal data",
#       "description": "Cloud Optimized GeoTIFF of boreal data"
#     }
#   },
#   "title": "Circumpolar boreal forest structure from ICESat-2 & HLS (2020 v1.0): 30m aboveground woody biomass density",
#   "extent": {
#     "spatial": {
#       "bbox": [
#         [
#           -180.0,
#           51.6,
#           180.0,
#           78.0
#         ]
#       ]
#     },
#     "temporal": {
#       "interval": [
#         [
#           "2019-01-01T00:00:00Z",
#           "2021-01-01T00:00:00Z"
#         ]
#       ]
#     }
#   },
#   "license": "CC-BY",
#   "providers": [
#     {
#       "name": "MAAP",
#       "description": "The MAAP platform is designed to combine data, algorithms, and computational abilities for the processing and sharing of data related to NASA\u2019s GEDI, ESA\u2019s BIOMASS, and NASA/ISRO\u2019s NISAR missions",
#       "roles": [
#         "host"
#       ],
#       "url": "https://maap-project.org"
#     }
#   ]
# }

# %%
# post collection to StacLoader
response = sns_client.publish(
    TopicArn=STAC_LOADER_SNS_TOPIC_ARN, Message=json.dumps(agb_1_0.to_dict())
)
print(response)
# Out:
# {'MessageId': 'a5f1d168-e1fc-50c7-bd28-b18490c33a85', 'ResponseMetadata': {'RequestId': '5bf39f7e-6fe4-5245-bb3d-ff921edb0807', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5bf39f7e-6fe4-5245-bb3d-ff921edb0807', 'date': 'Sat, 12 Jul 2025 14:19:43 GMT', 'content-type': 'text/xml', 'content-length': '294', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
